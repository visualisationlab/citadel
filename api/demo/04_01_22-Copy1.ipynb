# %%
import sys
import math
import random
from enum import Enum

import networkx as nx

from mesa import Agent, Model
from mesa.time import StagedActivation
from mesa.time import RandomActivation
from mesa.datacollection import DataCollector
from mesa.space import NetworkGrid

from mesa.visualization.modules import CanvasGrid
from mesa.visualization.ModularVisualization import ModularServer
from pyvis.network import Network

import math

from mesa.visualization.ModularVisualization import ModularServer
from mesa.visualization.UserParam import UserSettableParameter
from mesa.visualization.modules import ChartModule
from mesa.visualization.modules import NetworkModule
from mesa.visualization.modules import TextElement

import pandas as pd 
import numpy as np
import scipy.sparse as sps
import scipy as sp

import matplotlib.pyplot as plt

import multinetx as mx

# %%
def make_dict(role_list, dict_type):
    'This function will create color and name dictionaries necessary for the functioning of the model'
    'Be aware when changing this function, as it is not very versatile (it is mostly hardcoded)'
    
    if dict_type == 'color':
        return_dict = {role_list[0]: 'red'} | dict.fromkeys(role_list[1], 'orange') | \
        dict.fromkeys(role_list[2], 'yellow') | dict.fromkeys(role_list[3], 'firebrick') | \
        dict.fromkeys(role_list[4], 'green') | dict.fromkeys(role_list[5], 'darkred') | \
        dict.fromkeys(role_list[6], 'lime') | dict.fromkeys(role_list[7], 'crimson') | \
        dict.fromkeys(role_list[8], 'blue') | dict.fromkeys(role_list[9], 'orangered') | \
        dict.fromkeys(role_list[10], 'navy')  | dict.fromkeys(role_list[11], 'brown') | \
        dict.fromkeys(role_list[12], 'aqua') | dict.fromkeys(role_list[13], 'white') | \
        dict.fromkeys(role_list[14], 'pink') | dict.fromkeys(role_list[15], 'lightgreen') | \
        dict.fromkeys(role_list[16], 'limegreen') | dict.fromkeys(role_list[17], 'forestgreen') | \
        dict.fromkeys(role_list[18], 'olivedrab') 
        
    elif dict_type == 'business_name':
        return_dict = {role_list[0]: 'kingpin_main'} | \
        {c:'kingpin_'+str(i) for i, c in enumerate(role_list[1])} | \
        {c:'orphan_'+str(i) for i, c in enumerate(role_list[2])} | \
        {c:'exporteur_'+str(i) for i, c in enumerate(role_list[3])} | \
        {c:'chauffeur_'+str(i) for i, c in enumerate(role_list[4])} | \
        {c:'coordinator_'+str(i) for i, c in enumerate(role_list[5])}| \
        {c:'uithaaler_'+str(i) for i, c in enumerate(role_list[6])} | \
        {c:'handelaar_'+str(i) for i, c in enumerate(role_list[7])} | \
        {c:'transporteur_'+str(i) for i, c in enumerate(role_list[8])} | \
        {c:'financeer_'+str(i) for i, c in enumerate(role_list[9])} | \
        {c:'duane_'+str(i) for i, c in enumerate(role_list[10])} | \
        {c:'leverancier_'+str(i) for i, c in enumerate(role_list[11])} | \
        {c:'poortwachter_'+str(i) for i, c in enumerate(role_list[12])} | \
        {c:'stasher_'+str(i) for i, c in enumerate(role_list[13])}| \
        {c:'uithaalmakelaar_'+str(i) for i, c in enumerate(role_list[14])} | \
        {c:'plaatserbin_'+str(i) for i, c in enumerate(role_list[15])} | \
        {c:'beveiliger_'+str(i) for i, c in enumerate(role_list[16])} | \
        {c:'versneijder_'+str(i) for i, c in enumerate(role_list[17])} | \
        {c:'stroman_'+str(i) for i, c in enumerate(role_list[18])}
        
    elif dict_type == 'family_name':
        return_dict = {role_list[0]: 'father_main'} | \
        {c:'cousin_'+str(i) for i, c in enumerate(role_list[1])} | \
        {c:'brother_'+str(i) for i, c in enumerate(role_list[2])} | \
        {c:'friend_'+str(i) for i, c in enumerate(role_list[3])} | \
        {c:'driver_'+str(i) for i, c in enumerate(role_list[4])} | \
        {c:'contact_'+str(i) for i, c in enumerate(role_list[5])}| \
        {c:'mens_'+str(i) for i, c in enumerate(role_list[6])} | \
        {c:'human_'+str(i) for i, c in enumerate(role_list[7])} | \
        {c:'agent_'+str(i) for i, c in enumerate(role_list[8])} | \
        {c:'associate_'+str(i) for i, c in enumerate(role_list[9])} | \
        {c:'nephew_'+str(i) for i, c in enumerate(role_list[10])} | \
        {c:'niece_'+str(i) for i, c in enumerate(role_list[11])} | \
        {c:'person_'+str(i) for i, c in enumerate(role_list[12])} | \
        {c:'statue_'+str(i) for i, c in enumerate(role_list[13])} | \
        {c:'sister_'+str(i) for i, c in enumerate(role_list[14])} | \
        {c:'buurman_'+str(i) for i, c in enumerate(role_list[15])} | \
        {c:'colleague_'+str(i) for i, c in enumerate(role_list[16])} | \
        {c:'buddy_'+str(i) for i, c in enumerate(role_list[17])} | \
        {c:'mate_'+str(i) for i, c in enumerate(role_list[18])}
        
    elif dict_type == 'weight':
        return_dict = {role_list[0]: 100} | dict.fromkeys(role_list[1], 75) | \
        dict.fromkeys(role_list[2], 90) | dict.fromkeys(role_list[3], 50) | \
        dict.fromkeys(role_list[4], 40) | dict.fromkeys(role_list[5], 30) | \
        dict.fromkeys(role_list[6], 20) | dict.fromkeys(role_list[7], 10) | \
        dict.fromkeys(role_list[8], 5) | dict.fromkeys(role_list[9], 60) | \
        dict.fromkeys(role_list[10], 45) | dict.fromkeys(role_list[11], 50) | \
        dict.fromkeys(role_list[12], 25) | dict.fromkeys(role_list[13], 5) | \
        dict.fromkeys(role_list[14], 80) | dict.fromkeys(role_list[15], 5) | \
        dict.fromkeys(role_list[16], 5) | dict.fromkeys(role_list[17], 5) | \
        dict.fromkeys(role_list[18], 5)
    
    
    return return_dict

# %%
def add_edge_list(G, role_list1, role_list2, prob, role_color, role_weight, interconnected=False):
    'Function to add edges to a network according to some input parameters'
    'The interconnected variable indicates whether the first list of nodes should be connected among themselves'
    
    # Regular edges
    for c in role_list1:
        edge_list = []
        for x in role_list2:
            
            # Create edge with probability 'prob' 
            if ((c is not x) and (random.uniform(0, 1) < prob)):
                
                # Prevent double edges 
                if (c, x) in G.edges():
                    G.remove_edge(c, x)
                elif (x, c) in G.edges():
                    G.remove_edge(x, c)
                edge_list += [(c, x)]
        
        # Add edges to network
        G.add_edges_from(edge_list, color=role_color, weight=role_weight)   
    
    # Interconnected edges (connections between first group)
    if interconnected:
        for c in role_list1:
            edge_list = []
            for x in role_list1:
                
                # No loop-edges (edge to oneself)
                if c is not x:
                    
                    # Prevent double edges
                    if (c, x) in G.edges():
                        G.remove_edge(c, x)
                    elif (x, c) in G.edges():
                        G.remove_edge(x, c)
                    edge_list += [(c, x)]
            
            # Add edges to network
            G.add_edges_from(edge_list, color=role_color, weight=role_weight)

# %%
# NOTE: when changing the trust/violence variables in the dictionary, note that right now the numbers are 0.5, but
#       they should be between 0 and 1, as that is the case for all other trust/violence variables as well

edge_violence_social = {'FAT_COU': 0.5, 'FAT_BRO': 0.5, 'FAT_FRI': 0.5, 'FAT_DRI': 0.5, 'FAT_CON': 0.5, 'FAT_MEN': 0.5, 'FAT_HUM': 0.5, 'FAT_AGE': 0.5, 'FAT_ASC': 0.5, 'FAT_NEP': 0.5, 'FAT_NIE': 0.5, 'FAT_PER': 0.5, 'FAT_STT': 0.5, 'FAT_SIS': 0.5, 'FAT_BUR': 0.5, 'FAT_COL': 0.5, 'FAT_BUD': 0.5, 'FAT_MAT': 0.5,\
                     'COU_FAT': 0.5, 'COU_BRO': 0.5, 'COU_FRI': 0.5, 'COU_DRI': 0.5, 'COU_CON': 0.5, 'COU_MEN': 0.5, 'COU_HUM': 0.5, 'COU_AGE': 0.5, 'COU_ASC': 0.5, 'COU_NEP': 0.5, 'COU_NIE': 0.5, 'COU_PER': 0.5, 'COU_STT': 0.5, 'COU_SIS': 0.5, 'COU_BUR': 0.5, 'COU_COL': 0.5, 'COU_BUD': 0.5, 'COU_MAT': 0.5,\
                     'HUM_FAT': 0.5, 'HUM_BRO': 0.5, 'HUM_FRI': 0.5, 'HUM_DRI': 0.5, 'HUM_CON': 0.5, 'HUM_MEN': 0.5, 'HUM_COU': 0.5, 'HUM_AGE': 0.5, 'HUM_ASC': 0.5, 'HUM_NEP': 0.5, 'HUM_NIE': 0.5, 'HUM_PER': 0.5, 'HUM_STT': 0.5, 'HUM_SIS': 0.5, 'HUM_BUR': 0.5, 'HUM_COL': 0.5, 'HUM_BUD': 0.5, 'HUM_MAT': 0.5,\
                     'AGE_FAT': 0.5, 'AGE_BRO': 0.5, 'AGE_FRI': 0.5, 'AGE_DRI': 0.5, 'AGE_CON': 0.5, 'AGE_MEN': 0.5, 'AGE_HUM': 0.5, 'AGE_COU': 0.5, 'AGE_ASC': 0.5, 'AGE_NEP': 0.5, 'AGE_NIE': 0.5, 'AGE_PER': 0.5, 'AGE_STT': 0.5, 'AGE_SIS': 0.5, 'AGE_BUR': 0.5, 'AGE_COL': 0.5, 'AGE_BUD': 0.5, 'AGE_MAT': 0.5,\
                     'BRO_FAT': 0.5, 'BRO_COU': 0.5, 'BRO_FRI': 0.5, 'BRO_DRI': 0.5, 'BRO_CON': 0.5, 'BRO_MEN': 0.5, 'BRO_HUM': 0.5, 'BRO_AGE': 0.5, 'BRO_ASC': 0.5, 'BRO_NEP': 0.5, 'BRO_NIE': 0.5, 'BRO_PER': 0.5, 'BRO_STT': 0.5, 'BRO_SIS': 0.5, 'BRO_BUR': 0.5, 'BRO_COL': 0.5, 'BRO_BUD': 0.5, 'BRO_MAT': 0.5,\
                     'FRI_FAT': 0.5, 'FRI_COU': 0.5, 'FRI_BRO': 0.5, 'FRI_DRI': 0.5, 'FRI_CON': 0.5, 'FRI_MEN': 0.5, 'FRI_HUM': 0.5, 'FRI_AGE': 0.5, 'FRI_ASC': 0.5, 'FRI_NEP': 0.5, 'FRI_NIE': 0.5, 'FRI_PER': 0.5, 'FRI_STT': 0.5, 'FRI_SIS': 0.5, 'FRI_BUR': 0.5, 'FRI_COL': 0.5, 'FRI_BUD': 0.5, 'FRI_MAT': 0.5,\
                     'DRI_FAT': 0.5, 'DRI_COU': 0.5, 'DRI_BRO': 0.5, 'DRI_FRI': 0.5, 'DRI_CON': 0.5, 'DRI_MEN': 0.5, 'DRI_HUM': 0.5, 'DRI_AGE': 0.5, 'DRI_ASC': 0.5, 'DRI_NEP': 0.5, 'DRI_NIE': 0.5, 'DRI_PER': 0.5, 'DRI_STT': 0.5, 'DRI_SIS': 0.5, 'DRI_BUR': 0.5, 'DRI_COL': 0.5, 'DRI_BUD': 0.5, 'DRI_MAT': 0.5,\
                     'CON_FAT': 0.5, 'CON_COU': 0.5, 'CON_BRO': 0.5, 'CON_FRI': 0.5, 'CON_DRI': 0.5, 'CON_MEN': 0.5, 'CON_HUM': 0.5, 'CON_AGE': 0.5, 'CON_ASC': 0.5, 'CON_NEP': 0.5, 'CON_NIE': 0.5, 'CON_PER': 0.5, 'CON_STT': 0.5, 'CON_SIS': 0.5, 'CON_BUR': 0.5, 'CON_COL': 0.5, 'CON_BUD': 0.5, 'CON_MAT': 0.5,\
                     'ASC_FAT': 0.5, 'ASC_COU': 0.5, 'ASC_BRO': 0.5, 'ASC_FRI': 0.5, 'ASC_DRI': 0.5, 'ASC_MEN': 0.5, 'ASC_HUM': 0.5, 'ASC_AGE': 0.5, 'ASC_CON': 0.5, 'ASC_NEP': 0.5, 'ASC_NIE': 0.5, 'ASC_PER': 0.5, 'ASC_STT': 0.5, 'ASC_SIS': 0.5, 'ASC_BUR': 0.5, 'ASC_COL': 0.5, 'ASC_BUD': 0.5, 'ASC_MAT': 0.5,\
                     'NEP_FAT': 0.5, 'NEP_COU': 0.5, 'NEP_BRO': 0.5, 'NEP_FRI': 0.5, 'NEP_DRI': 0.5, 'NEP_MEN': 0.5, 'NEP_HUM': 0.5, 'NEP_AGE': 0.5, 'NEP_ASC': 0.5, 'NEP_CON': 0.5, 'NEP_NIE': 0.5, 'NEP_PER': 0.5, 'NEP_STT': 0.5, 'NEP_SIS': 0.5, 'NEP_BUR': 0.5, 'NEP_COL': 0.5, 'NEP_BUD': 0.5, 'NEP_MAT': 0.5,\
                     'NIE_FAT': 0.5, 'NIE_COU': 0.5, 'NIE_BRO': 0.5, 'NIE_FRI': 0.5, 'NIE_DRI': 0.5, 'NIE_MEN': 0.5, 'NIE_HUM': 0.5, 'NIE_AGE': 0.5, 'NIE_ASC': 0.5, 'NIE_CON': 0.5, 'NIE_NEP': 0.5, 'NIE_PER': 0.5, 'NIE_STT': 0.5, 'NIE_SIS': 0.5, 'NIE_BUR': 0.5, 'NIE_COL': 0.5, 'NIE_BUD': 0.5, 'NIE_MAT': 0.5,\
                     'MEN_FAT': 0.5, 'MEN_BRO': 0.5, 'MEN_FRI': 0.5, 'MEN_DRI': 0.5, 'MEN_CON': 0.5, 'MEN_COU': 0.5, 'MEN_HUM': 0.5, 'MEN_AGE': 0.5, 'MEN_ASC': 0.5, 'MEN_NEP': 0.5, 'MEN_NIE': 0.5, 'MEN_PER': 0.5, 'MEN_STT': 0.5, 'MEN_SIS': 0.5, 'MEN_BUR': 0.5, 'MEN_COL': 0.5, 'MEN_BUD': 0.5, 'MEN_MAT': 0.5,\
                     'PER_FAT': 0.5, 'PER_BRO': 0.5, 'PER_FRI': 0.5, 'PER_DRI': 0.5, 'PER_CON': 0.5, 'PER_COU': 0.5, 'PER_HUM': 0.5, 'PER_AGE': 0.5, 'PER_ASC': 0.5, 'PER_NEP': 0.5, 'PER_NIE': 0.5, 'PER_MEN': 0.5, 'PER_STT': 0.5, 'PER_SIS': 0.5, 'PER_BUR': 0.5, 'PER_COL': 0.5, 'PER_BUD': 0.5, 'PER_MAT': 0.5,\
                     'STT_FAT': 0.5, 'STT_BRO': 0.5, 'STT_FRI': 0.5, 'STT_DRI': 0.5, 'STT_CON': 0.5, 'STT_COU': 0.5, 'STT_HUM': 0.5, 'STT_AGE': 0.5, 'STT_ASC': 0.5, 'STT_NEP': 0.5, 'STT_NIE': 0.5, 'STT_MEN': 0.5, 'STT_PER': 0.5, 'STT_SIS': 0.5, 'STT_BUR': 0.5, 'STT_COL': 0.5, 'STT_BUD': 0.5, 'STT_MAT': 0.5,\
                     'SIS_FAT': 0.5, 'SIS_BRO': 0.5, 'SIS_FRI': 0.5, 'SIS_DRI': 0.5, 'SIS_CON': 0.5, 'SIS_COU': 0.5, 'SIS_HUM': 0.5, 'SIS_AGE': 0.5, 'SIS_ASC': 0.5, 'SIS_NEP': 0.5, 'SIS_NIE': 0.5, 'SIS_MEN': 0.5, 'SIS_PER': 0.5, 'SIS_STT': 0.5, 'SIS_BUR': 0.5, 'SIS_COL': 0.5, 'SIS_BUD': 0.5, 'SIS_MAT': 0.5,\
                     'BUR_FAT': 0.5, 'BUR_BRO': 0.5, 'BUR_FRI': 0.5, 'BUR_DRI': 0.5, 'BUR_CON': 0.5, 'BUR_COU': 0.5, 'BUR_HUM': 0.5, 'BUR_AGE': 0.5, 'BUR_ASC': 0.5, 'BUR_NEP': 0.5, 'BUR_NIE': 0.5, 'BUR_MEN': 0.5, 'BUR_PER': 0.5, 'BUR_STT': 0.5, 'BUR_SIS': 0.5, 'BUR_COL': 0.5, 'BUR_BUD': 0.5, 'BUR_MAT': 0.5,\
                     'COL_FAT': 0.5, 'COL_BRO': 0.5, 'COL_FRI': 0.5, 'COL_DRI': 0.5, 'COL_CON': 0.5, 'COL_COU': 0.5, 'COL_HUM': 0.5, 'COL_AGE': 0.5, 'COL_ASC': 0.5, 'COL_NEP': 0.5, 'COL_NIE': 0.5, 'COL_MEN': 0.5, 'COL_PER': 0.5, 'COL_STT': 0.5, 'COL_SIS': 0.5, 'COL_BUD': 0.5, 'COL_BUR': 0.5, 'COL_MAT': 0.5,\
                     'BUD_FAT': 0.5, 'BUD_BRO': 0.5, 'BUD_FRI': 0.5, 'BUD_DRI': 0.5, 'BUD_CON': 0.5, 'BUD_COU': 0.5, 'BUD_HUM': 0.5, 'BUD_AGE': 0.5, 'BUD_ASC': 0.5, 'BUD_NEP': 0.5, 'BUD_NIE': 0.5, 'BUD_MEN': 0.5, 'BUD_PER': 0.5, 'BUD_STT': 0.5, 'BUD_SIS': 0.5, 'BUD_COL': 0.5, 'BUD_BUR': 0.5, 'BUD_MAT': 0.5,\
                     'MAT_FAT': 0.5, 'MAT_BRO': 0.5, 'MAT_FRI': 0.5, 'MAT_DRI': 0.5, 'MAT_CON': 0.5, 'MAT_COU': 0.5, 'MAT_HUM': 0.5, 'MAT_AGE': 0.5, 'MAT_ASC': 0.5, 'MAT_NEP': 0.5, 'MAT_NIE': 0.5, 'MAT_MEN': 0.5, 'MAT_PER': 0.5, 'MAT_STT': 0.5, 'MAT_SIS': 0.5, 'MAT_COL': 0.5, 'MAT_BUR': 0.5, 'MAT_BUD': 0.5,\
                     'COU_COU': 0.5, 'BRO_BRO': 0.5, 'FRI_FRI': 0.5, 'DRI_DRI': 0.5, 'CON_CON': 0.5, 'MEN_MEN': 0.5, 'HUM_HUM': 0.5, 'AGE_AGE': 0.5, 'ASC_ASC': 0.5, 'NEP_NEP': 0.5, 'NIE_NIE': 0.5, 'PER_PER': 0.5, 'STT_STT': 0.5, 'SIS_SIS': 0.5, 'BUR_BUR': 0.5, 'COL_COL': 0.5, 'BUD_BUD': 0.5, 'MAT_MAT': 0.5,}


edge_trust_social =  {'FAT_COU': 0.5, 'FAT_BRO': 0.5, 'FAT_FRI': 0.5, 'FAT_DRI': 0.5, 'FAT_CON': 0.5, 'FAT_MEN': 0.5, 'FAT_HUM': 0.5, 'FAT_AGE': 0.5, 'FAT_ASC': 0.5, 'FAT_NEP': 0.5, 'FAT_NIE': 0.5, 'FAT_PER': 0.5, 'FAT_STT': 0.5, 'FAT_SIS': 0.5, 'FAT_BUR': 0.5, 'FAT_COL': 0.5, 'FAT_BUD': 0.5, 'FAT_MAT': 0.5,\
                     'COU_FAT': 0.5, 'COU_BRO': 0.5, 'COU_FRI': 0.5, 'COU_DRI': 0.5, 'COU_CON': 0.5, 'COU_MEN': 0.5, 'COU_HUM': 0.5, 'COU_AGE': 0.5, 'COU_ASC': 0.5, 'COU_NEP': 0.5, 'COU_NIE': 0.5, 'COU_PER': 0.5, 'COU_STT': 0.5, 'COU_SIS': 0.5, 'COU_BUR': 0.5, 'COU_COL': 0.5, 'COU_BUD': 0.5, 'COU_MAT': 0.5,\
                     'HUM_FAT': 0.5, 'HUM_BRO': 0.5, 'HUM_FRI': 0.5, 'HUM_DRI': 0.5, 'HUM_CON': 0.5, 'HUM_MEN': 0.5, 'HUM_COU': 0.5, 'HUM_AGE': 0.5, 'HUM_ASC': 0.5, 'HUM_NEP': 0.5, 'HUM_NIE': 0.5, 'HUM_PER': 0.5, 'HUM_STT': 0.5, 'HUM_SIS': 0.5, 'HUM_BUR': 0.5, 'HUM_COL': 0.5, 'HUM_BUD': 0.5, 'HUM_MAT': 0.5,\
                     'AGE_FAT': 0.5, 'AGE_BRO': 0.5, 'AGE_FRI': 0.5, 'AGE_DRI': 0.5, 'AGE_CON': 0.5, 'AGE_MEN': 0.5, 'AGE_HUM': 0.5, 'AGE_COU': 0.5, 'AGE_ASC': 0.5, 'AGE_NEP': 0.5, 'AGE_NIE': 0.5, 'AGE_PER': 0.5, 'AGE_STT': 0.5, 'AGE_SIS': 0.5, 'AGE_BUR': 0.5, 'AGE_COL': 0.5, 'AGE_BUD': 0.5, 'AGE_MAT': 0.5,\
                     'BRO_FAT': 0.5, 'BRO_COU': 0.5, 'BRO_FRI': 0.5, 'BRO_DRI': 0.5, 'BRO_CON': 0.5, 'BRO_MEN': 0.5, 'BRO_HUM': 0.5, 'BRO_AGE': 0.5, 'BRO_ASC': 0.5, 'BRO_NEP': 0.5, 'BRO_NIE': 0.5, 'BRO_PER': 0.5, 'BRO_STT': 0.5, 'BRO_SIS': 0.5, 'BRO_BUR': 0.5, 'BRO_COL': 0.5, 'BRO_BUD': 0.5, 'BRO_MAT': 0.5,\
                     'FRI_FAT': 0.5, 'FRI_COU': 0.5, 'FRI_BRO': 0.5, 'FRI_DRI': 0.5, 'FRI_CON': 0.5, 'FRI_MEN': 0.5, 'FRI_HUM': 0.5, 'FRI_AGE': 0.5, 'FRI_ASC': 0.5, 'FRI_NEP': 0.5, 'FRI_NIE': 0.5, 'FRI_PER': 0.5, 'FRI_STT': 0.5, 'FRI_SIS': 0.5, 'FRI_BUR': 0.5, 'FRI_COL': 0.5, 'FRI_BUD': 0.5, 'FRI_MAT': 0.5,\
                     'DRI_FAT': 0.5, 'DRI_COU': 0.5, 'DRI_BRO': 0.5, 'DRI_FRI': 0.5, 'DRI_CON': 0.5, 'DRI_MEN': 0.5, 'DRI_HUM': 0.5, 'DRI_AGE': 0.5, 'DRI_ASC': 0.5, 'DRI_NEP': 0.5, 'DRI_NIE': 0.5, 'DRI_PER': 0.5, 'DRI_STT': 0.5, 'DRI_SIS': 0.5, 'DRI_BUR': 0.5, 'DRI_COL': 0.5, 'DRI_BUD': 0.5, 'DRI_MAT': 0.5,\
                     'CON_FAT': 0.5, 'CON_COU': 0.5, 'CON_BRO': 0.5, 'CON_FRI': 0.5, 'CON_DRI': 0.5, 'CON_MEN': 0.5, 'CON_HUM': 0.5, 'CON_AGE': 0.5, 'CON_ASC': 0.5, 'CON_NEP': 0.5, 'CON_NIE': 0.5, 'CON_PER': 0.5, 'CON_STT': 0.5, 'CON_SIS': 0.5, 'CON_BUR': 0.5, 'CON_COL': 0.5, 'CON_BUD': 0.5, 'CON_MAT': 0.5,\
                     'ASC_FAT': 0.5, 'ASC_COU': 0.5, 'ASC_BRO': 0.5, 'ASC_FRI': 0.5, 'ASC_DRI': 0.5, 'ASC_MEN': 0.5, 'ASC_HUM': 0.5, 'ASC_AGE': 0.5, 'ASC_CON': 0.5, 'ASC_NEP': 0.5, 'ASC_NIE': 0.5, 'ASC_PER': 0.5, 'ASC_STT': 0.5, 'ASC_SIS': 0.5, 'ASC_BUR': 0.5, 'ASC_COL': 0.5, 'ASC_BUD': 0.5, 'ASC_MAT': 0.5,\
                     'NEP_FAT': 0.5, 'NEP_COU': 0.5, 'NEP_BRO': 0.5, 'NEP_FRI': 0.5, 'NEP_DRI': 0.5, 'NEP_MEN': 0.5, 'NEP_HUM': 0.5, 'NEP_AGE': 0.5, 'NEP_ASC': 0.5, 'NEP_CON': 0.5, 'NEP_NIE': 0.5, 'NEP_PER': 0.5, 'NEP_STT': 0.5, 'NEP_SIS': 0.5, 'NEP_BUR': 0.5, 'NEP_COL': 0.5, 'NEP_BUD': 0.5, 'NEP_MAT': 0.5,\
                     'NIE_FAT': 0.5, 'NIE_COU': 0.5, 'NIE_BRO': 0.5, 'NIE_FRI': 0.5, 'NIE_DRI': 0.5, 'NIE_MEN': 0.5, 'NIE_HUM': 0.5, 'NIE_AGE': 0.5, 'NIE_ASC': 0.5, 'NIE_CON': 0.5, 'NIE_NEP': 0.5, 'NIE_PER': 0.5, 'NIE_STT': 0.5, 'NIE_SIS': 0.5, 'NIE_BUR': 0.5, 'NIE_COL': 0.5, 'NIE_BUD': 0.5, 'NIE_MAT': 0.5,\
                     'MEN_FAT': 0.5, 'MEN_BRO': 0.5, 'MEN_FRI': 0.5, 'MEN_DRI': 0.5, 'MEN_CON': 0.5, 'MEN_COU': 0.5, 'MEN_HUM': 0.5, 'MEN_AGE': 0.5, 'MEN_ASC': 0.5, 'MEN_NEP': 0.5, 'MEN_NIE': 0.5, 'MEN_PER': 0.5, 'MEN_STT': 0.5, 'MEN_SIS': 0.5, 'MEN_BUR': 0.5, 'MEN_COL': 0.5, 'MEN_BUD': 0.5, 'MEN_MAT': 0.5,\
                     'PER_FAT': 0.5, 'PER_BRO': 0.5, 'PER_FRI': 0.5, 'PER_DRI': 0.5, 'PER_CON': 0.5, 'PER_COU': 0.5, 'PER_HUM': 0.5, 'PER_AGE': 0.5, 'PER_ASC': 0.5, 'PER_NEP': 0.5, 'PER_NIE': 0.5, 'PER_MEN': 0.5, 'PER_STT': 0.5, 'PER_SIS': 0.5, 'PER_BUR': 0.5, 'PER_COL': 0.5, 'PER_BUD': 0.5, 'PER_MAT': 0.5,\
                     'STT_FAT': 0.5, 'STT_BRO': 0.5, 'STT_FRI': 0.5, 'STT_DRI': 0.5, 'STT_CON': 0.5, 'STT_COU': 0.5, 'STT_HUM': 0.5, 'STT_AGE': 0.5, 'STT_ASC': 0.5, 'STT_NEP': 0.5, 'STT_NIE': 0.5, 'STT_MEN': 0.5, 'STT_PER': 0.5, 'STT_SIS': 0.5, 'STT_BUR': 0.5, 'STT_COL': 0.5, 'STT_BUD': 0.5, 'STT_MAT': 0.5,\
                     'SIS_FAT': 0.5, 'SIS_BRO': 0.5, 'SIS_FRI': 0.5, 'SIS_DRI': 0.5, 'SIS_CON': 0.5, 'SIS_COU': 0.5, 'SIS_HUM': 0.5, 'SIS_AGE': 0.5, 'SIS_ASC': 0.5, 'SIS_NEP': 0.5, 'SIS_NIE': 0.5, 'SIS_MEN': 0.5, 'SIS_PER': 0.5, 'SIS_STT': 0.5, 'SIS_BUR': 0.5, 'SIS_COL': 0.5, 'SIS_BUD': 0.5, 'SIS_MAT': 0.5,\
                     'BUR_FAT': 0.5, 'BUR_BRO': 0.5, 'BUR_FRI': 0.5, 'BUR_DRI': 0.5, 'BUR_CON': 0.5, 'BUR_COU': 0.5, 'BUR_HUM': 0.5, 'BUR_AGE': 0.5, 'BUR_ASC': 0.5, 'BUR_NEP': 0.5, 'BUR_NIE': 0.5, 'BUR_MEN': 0.5, 'BUR_PER': 0.5, 'BUR_STT': 0.5, 'BUR_SIS': 0.5, 'BUR_COL': 0.5, 'BUR_BUD': 0.5, 'BUR_MAT': 0.5,\
                     'COL_FAT': 0.5, 'COL_BRO': 0.5, 'COL_FRI': 0.5, 'COL_DRI': 0.5, 'COL_CON': 0.5, 'COL_COU': 0.5, 'COL_HUM': 0.5, 'COL_AGE': 0.5, 'COL_ASC': 0.5, 'COL_NEP': 0.5, 'COL_NIE': 0.5, 'COL_MEN': 0.5, 'COL_PER': 0.5, 'COL_STT': 0.5, 'COL_SIS': 0.5, 'COL_BUD': 0.5, 'COL_BUR': 0.5, 'COL_MAT': 0.5,\
                     'BUD_FAT': 0.5, 'BUD_BRO': 0.5, 'BUD_FRI': 0.5, 'BUD_DRI': 0.5, 'BUD_CON': 0.5, 'BUD_COU': 0.5, 'BUD_HUM': 0.5, 'BUD_AGE': 0.5, 'BUD_ASC': 0.5, 'BUD_NEP': 0.5, 'BUD_NIE': 0.5, 'BUD_MEN': 0.5, 'BUD_PER': 0.5, 'BUD_STT': 0.5, 'BUD_SIS': 0.5, 'BUD_COL': 0.5, 'BUD_BUR': 0.5, 'BUD_MAT': 0.5,\
                     'MAT_FAT': 0.5, 'MAT_BRO': 0.5, 'MAT_FRI': 0.5, 'MAT_DRI': 0.5, 'MAT_CON': 0.5, 'MAT_COU': 0.5, 'MAT_HUM': 0.5, 'MAT_AGE': 0.5, 'MAT_ASC': 0.5, 'MAT_NEP': 0.5, 'MAT_NIE': 0.5, 'MAT_MEN': 0.5, 'MAT_PER': 0.5, 'MAT_STT': 0.5, 'MAT_SIS': 0.5, 'MAT_COL': 0.5, 'MAT_BUR': 0.5, 'MAT_BUD': 0.5,\
                     'COU_COU': 0.5, 'BRO_BRO': 0.5, 'FRI_FRI': 0.5, 'DRI_DRI': 0.5, 'CON_CON': 0.5, 'MEN_MEN': 0.5, 'HUM_HUM': 0.5, 'AGE_AGE': 0.5, 'ASC_ASC': 0.5, 'NEP_NEP': 0.5, 'NIE_NIE': 0.5, 'PER_PER': 0.5, 'STT_STT': 0.5, 'SIS_SIS': 0.5, 'BUR_BUR': 0.5, 'COL_COL': 0.5, 'BUD_BUD': 0.5, 'MAT_MAT': 0.5,}


edge_crimecapital_social =  {'FAT_COU': 0.5, 'FAT_BRO': 0.5, 'FAT_FRI': 0.5, 'FAT_DRI': 0.5, 'FAT_CON': 0.5, 'FAT_MEN': 0.5, 'FAT_HUM': 0.5, 'FAT_AGE': 0.5, 'FAT_ASC': 0.5, 'FAT_NEP': 0.5, 'FAT_NIE': 0.5, 'FAT_PER': 0.5, 'FAT_STT': 0.5, 'FAT_SIS': 0.5, 'FAT_BUR': 0.5, 'FAT_COL': 0.5, 'FAT_BUD': 0.5, 'FAT_MAT': 0.5,\
                     'COU_FAT': 0.5, 'COU_BRO': 0.5, 'COU_FRI': 0.5, 'COU_DRI': 0.5, 'COU_CON': 0.5, 'COU_MEN': 0.5, 'COU_HUM': 0.5, 'COU_AGE': 0.5, 'COU_ASC': 0.5, 'COU_NEP': 0.5, 'COU_NIE': 0.5, 'COU_PER': 0.5, 'COU_STT': 0.5, 'COU_SIS': 0.5, 'COU_BUR': 0.5, 'COU_COL': 0.5, 'COU_BUD': 0.5, 'COU_MAT': 0.5,\
                     'HUM_FAT': 0.5, 'HUM_BRO': 0.5, 'HUM_FRI': 0.5, 'HUM_DRI': 0.5, 'HUM_CON': 0.5, 'HUM_MEN': 0.5, 'HUM_COU': 0.5, 'HUM_AGE': 0.5, 'HUM_ASC': 0.5, 'HUM_NEP': 0.5, 'HUM_NIE': 0.5, 'HUM_PER': 0.5, 'HUM_STT': 0.5, 'HUM_SIS': 0.5, 'HUM_BUR': 0.5, 'HUM_COL': 0.5, 'HUM_BUD': 0.5, 'HUM_MAT': 0.5,\
                     'AGE_FAT': 0.5, 'AGE_BRO': 0.5, 'AGE_FRI': 0.5, 'AGE_DRI': 0.5, 'AGE_CON': 0.5, 'AGE_MEN': 0.5, 'AGE_HUM': 0.5, 'AGE_COU': 0.5, 'AGE_ASC': 0.5, 'AGE_NEP': 0.5, 'AGE_NIE': 0.5, 'AGE_PER': 0.5, 'AGE_STT': 0.5, 'AGE_SIS': 0.5, 'AGE_BUR': 0.5, 'AGE_COL': 0.5, 'AGE_BUD': 0.5, 'AGE_MAT': 0.5,\
                     'BRO_FAT': 0.5, 'BRO_COU': 0.5, 'BRO_FRI': 0.5, 'BRO_DRI': 0.5, 'BRO_CON': 0.5, 'BRO_MEN': 0.5, 'BRO_HUM': 0.5, 'BRO_AGE': 0.5, 'BRO_ASC': 0.5, 'BRO_NEP': 0.5, 'BRO_NIE': 0.5, 'BRO_PER': 0.5, 'BRO_STT': 0.5, 'BRO_SIS': 0.5, 'BRO_BUR': 0.5, 'BRO_COL': 0.5, 'BRO_BUD': 0.5, 'BRO_MAT': 0.5,\
                     'FRI_FAT': 0.5, 'FRI_COU': 0.5, 'FRI_BRO': 0.5, 'FRI_DRI': 0.5, 'FRI_CON': 0.5, 'FRI_MEN': 0.5, 'FRI_HUM': 0.5, 'FRI_AGE': 0.5, 'FRI_ASC': 0.5, 'FRI_NEP': 0.5, 'FRI_NIE': 0.5, 'FRI_PER': 0.5, 'FRI_STT': 0.5, 'FRI_SIS': 0.5, 'FRI_BUR': 0.5, 'FRI_COL': 0.5, 'FRI_BUD': 0.5, 'FRI_MAT': 0.5,\
                     'DRI_FAT': 0.5, 'DRI_COU': 0.5, 'DRI_BRO': 0.5, 'DRI_FRI': 0.5, 'DRI_CON': 0.5, 'DRI_MEN': 0.5, 'DRI_HUM': 0.5, 'DRI_AGE': 0.5, 'DRI_ASC': 0.5, 'DRI_NEP': 0.5, 'DRI_NIE': 0.5, 'DRI_PER': 0.5, 'DRI_STT': 0.5, 'DRI_SIS': 0.5, 'DRI_BUR': 0.5, 'DRI_COL': 0.5, 'DRI_BUD': 0.5, 'DRI_MAT': 0.5,\
                     'CON_FAT': 0.5, 'CON_COU': 0.5, 'CON_BRO': 0.5, 'CON_FRI': 0.5, 'CON_DRI': 0.5, 'CON_MEN': 0.5, 'CON_HUM': 0.5, 'CON_AGE': 0.5, 'CON_ASC': 0.5, 'CON_NEP': 0.5, 'CON_NIE': 0.5, 'CON_PER': 0.5, 'CON_STT': 0.5, 'CON_SIS': 0.5, 'CON_BUR': 0.5, 'CON_COL': 0.5, 'CON_BUD': 0.5, 'CON_MAT': 0.5,\
                     'ASC_FAT': 0.5, 'ASC_COU': 0.5, 'ASC_BRO': 0.5, 'ASC_FRI': 0.5, 'ASC_DRI': 0.5, 'ASC_MEN': 0.5, 'ASC_HUM': 0.5, 'ASC_AGE': 0.5, 'ASC_CON': 0.5, 'ASC_NEP': 0.5, 'ASC_NIE': 0.5, 'ASC_PER': 0.5, 'ASC_STT': 0.5, 'ASC_SIS': 0.5, 'ASC_BUR': 0.5, 'ASC_COL': 0.5, 'ASC_BUD': 0.5, 'ASC_MAT': 0.5,\
                     'NEP_FAT': 0.5, 'NEP_COU': 0.5, 'NEP_BRO': 0.5, 'NEP_FRI': 0.5, 'NEP_DRI': 0.5, 'NEP_MEN': 0.5, 'NEP_HUM': 0.5, 'NEP_AGE': 0.5, 'NEP_ASC': 0.5, 'NEP_CON': 0.5, 'NEP_NIE': 0.5, 'NEP_PER': 0.5, 'NEP_STT': 0.5, 'NEP_SIS': 0.5, 'NEP_BUR': 0.5, 'NEP_COL': 0.5, 'NEP_BUD': 0.5, 'NEP_MAT': 0.5,\
                     'NIE_FAT': 0.5, 'NIE_COU': 0.5, 'NIE_BRO': 0.5, 'NIE_FRI': 0.5, 'NIE_DRI': 0.5, 'NIE_MEN': 0.5, 'NIE_HUM': 0.5, 'NIE_AGE': 0.5, 'NIE_ASC': 0.5, 'NIE_CON': 0.5, 'NIE_NEP': 0.5, 'NIE_PER': 0.5, 'NIE_STT': 0.5, 'NIE_SIS': 0.5, 'NIE_BUR': 0.5, 'NIE_COL': 0.5, 'NIE_BUD': 0.5, 'NIE_MAT': 0.5,\
                     'MEN_FAT': 0.5, 'MEN_BRO': 0.5, 'MEN_FRI': 0.5, 'MEN_DRI': 0.5, 'MEN_CON': 0.5, 'MEN_COU': 0.5, 'MEN_HUM': 0.5, 'MEN_AGE': 0.5, 'MEN_ASC': 0.5, 'MEN_NEP': 0.5, 'MEN_NIE': 0.5, 'MEN_PER': 0.5, 'MEN_STT': 0.5, 'MEN_SIS': 0.5, 'MEN_BUR': 0.5, 'MEN_COL': 0.5, 'MEN_BUD': 0.5, 'MEN_MAT': 0.5,\
                     'PER_FAT': 0.5, 'PER_BRO': 0.5, 'PER_FRI': 0.5, 'PER_DRI': 0.5, 'PER_CON': 0.5, 'PER_COU': 0.5, 'PER_HUM': 0.5, 'PER_AGE': 0.5, 'PER_ASC': 0.5, 'PER_NEP': 0.5, 'PER_NIE': 0.5, 'PER_MEN': 0.5, 'PER_STT': 0.5, 'PER_SIS': 0.5, 'PER_BUR': 0.5, 'PER_COL': 0.5, 'PER_BUD': 0.5, 'PER_MAT': 0.5,\
                     'STT_FAT': 0.5, 'STT_BRO': 0.5, 'STT_FRI': 0.5, 'STT_DRI': 0.5, 'STT_CON': 0.5, 'STT_COU': 0.5, 'STT_HUM': 0.5, 'STT_AGE': 0.5, 'STT_ASC': 0.5, 'STT_NEP': 0.5, 'STT_NIE': 0.5, 'STT_MEN': 0.5, 'STT_PER': 0.5, 'STT_SIS': 0.5, 'STT_BUR': 0.5, 'STT_COL': 0.5, 'STT_BUD': 0.5, 'STT_MAT': 0.5,\
                     'SIS_FAT': 0.5, 'SIS_BRO': 0.5, 'SIS_FRI': 0.5, 'SIS_DRI': 0.5, 'SIS_CON': 0.5, 'SIS_COU': 0.5, 'SIS_HUM': 0.5, 'SIS_AGE': 0.5, 'SIS_ASC': 0.5, 'SIS_NEP': 0.5, 'SIS_NIE': 0.5, 'SIS_MEN': 0.5, 'SIS_PER': 0.5, 'SIS_STT': 0.5, 'SIS_BUR': 0.5, 'SIS_COL': 0.5, 'SIS_BUD': 0.5, 'SIS_MAT': 0.5,\
                     'BUR_FAT': 0.5, 'BUR_BRO': 0.5, 'BUR_FRI': 0.5, 'BUR_DRI': 0.5, 'BUR_CON': 0.5, 'BUR_COU': 0.5, 'BUR_HUM': 0.5, 'BUR_AGE': 0.5, 'BUR_ASC': 0.5, 'BUR_NEP': 0.5, 'BUR_NIE': 0.5, 'BUR_MEN': 0.5, 'BUR_PER': 0.5, 'BUR_STT': 0.5, 'BUR_SIS': 0.5, 'BUR_COL': 0.5, 'BUR_BUD': 0.5, 'BUR_MAT': 0.5,\
                     'COL_FAT': 0.5, 'COL_BRO': 0.5, 'COL_FRI': 0.5, 'COL_DRI': 0.5, 'COL_CON': 0.5, 'COL_COU': 0.5, 'COL_HUM': 0.5, 'COL_AGE': 0.5, 'COL_ASC': 0.5, 'COL_NEP': 0.5, 'COL_NIE': 0.5, 'COL_MEN': 0.5, 'COL_PER': 0.5, 'COL_STT': 0.5, 'COL_SIS': 0.5, 'COL_BUD': 0.5, 'COL_BUR': 0.5, 'COL_MAT': 0.5,\
                     'BUD_FAT': 0.5, 'BUD_BRO': 0.5, 'BUD_FRI': 0.5, 'BUD_DRI': 0.5, 'BUD_CON': 0.5, 'BUD_COU': 0.5, 'BUD_HUM': 0.5, 'BUD_AGE': 0.5, 'BUD_ASC': 0.5, 'BUD_NEP': 0.5, 'BUD_NIE': 0.5, 'BUD_MEN': 0.5, 'BUD_PER': 0.5, 'BUD_STT': 0.5, 'BUD_SIS': 0.5, 'BUD_COL': 0.5, 'BUD_BUR': 0.5, 'BUD_MAT': 0.5,\
                     'MAT_FAT': 0.5, 'MAT_BRO': 0.5, 'MAT_FRI': 0.5, 'MAT_DRI': 0.5, 'MAT_CON': 0.5, 'MAT_COU': 0.5, 'MAT_HUM': 0.5, 'MAT_AGE': 0.5, 'MAT_ASC': 0.5, 'MAT_NEP': 0.5, 'MAT_NIE': 0.5, 'MAT_MEN': 0.5, 'MAT_PER': 0.5, 'MAT_STT': 0.5, 'MAT_SIS': 0.5, 'MAT_COL': 0.5, 'MAT_BUR': 0.5, 'MAT_BUD': 0.5,\
                     'COU_COU': 0.5, 'BRO_BRO': 0.5, 'FRI_FRI': 0.5, 'DRI_DRI': 0.5, 'CON_CON': 0.5, 'MEN_MEN': 0.5, 'HUM_HUM': 0.5, 'AGE_AGE': 0.5, 'ASC_ASC': 0.5, 'NEP_NEP': 0.5, 'NIE_NIE': 0.5, 'PER_PER': 0.5, 'STT_STT': 0.5, 'SIS_SIS': 0.5, 'BUR_BUR': 0.5, 'COL_COL': 0.5, 'BUD_BUD': 0.5, 'MAT_MAT': 0.5,}


edge_financialkracht_social =   {'FAT_COU': 0.5, 'FAT_BRO': 0.5, 'FAT_FRI': 0.5, 'FAT_DRI': 0.5, 'FAT_CON': 0.5, 'FAT_MEN': 0.5, 'FAT_HUM': 0.5, 'FAT_AGE': 0.5, 'FAT_ASC': 0.5, 'FAT_NEP': 0.5, 'FAT_NIE': 0.5, 'FAT_PER': 0.5, 'FAT_STT': 0.5, 'FAT_SIS': 0.5, 'FAT_BUR': 0.5, 'FAT_COL': 0.5, 'FAT_BUD': 0.5, 'FAT_MAT': 0.5,\
                     'COU_FAT': 0.5, 'COU_BRO': 0.5, 'COU_FRI': 0.5, 'COU_DRI': 0.5, 'COU_CON': 0.5, 'COU_MEN': 0.5, 'COU_HUM': 0.5, 'COU_AGE': 0.5, 'COU_ASC': 0.5, 'COU_NEP': 0.5, 'COU_NIE': 0.5, 'COU_PER': 0.5, 'COU_STT': 0.5, 'COU_SIS': 0.5, 'COU_BUR': 0.5, 'COU_COL': 0.5, 'COU_BUD': 0.5, 'COU_MAT': 0.5,\
                     'HUM_FAT': 0.5, 'HUM_BRO': 0.5, 'HUM_FRI': 0.5, 'HUM_DRI': 0.5, 'HUM_CON': 0.5, 'HUM_MEN': 0.5, 'HUM_COU': 0.5, 'HUM_AGE': 0.5, 'HUM_ASC': 0.5, 'HUM_NEP': 0.5, 'HUM_NIE': 0.5, 'HUM_PER': 0.5, 'HUM_STT': 0.5, 'HUM_SIS': 0.5, 'HUM_BUR': 0.5, 'HUM_COL': 0.5, 'HUM_BUD': 0.5, 'HUM_MAT': 0.5,\
                     'AGE_FAT': 0.5, 'AGE_BRO': 0.5, 'AGE_FRI': 0.5, 'AGE_DRI': 0.5, 'AGE_CON': 0.5, 'AGE_MEN': 0.5, 'AGE_HUM': 0.5, 'AGE_COU': 0.5, 'AGE_ASC': 0.5, 'AGE_NEP': 0.5, 'AGE_NIE': 0.5, 'AGE_PER': 0.5, 'AGE_STT': 0.5, 'AGE_SIS': 0.5, 'AGE_BUR': 0.5, 'AGE_COL': 0.5, 'AGE_BUD': 0.5, 'AGE_MAT': 0.5,\
                     'BRO_FAT': 0.5, 'BRO_COU': 0.5, 'BRO_FRI': 0.5, 'BRO_DRI': 0.5, 'BRO_CON': 0.5, 'BRO_MEN': 0.5, 'BRO_HUM': 0.5, 'BRO_AGE': 0.5, 'BRO_ASC': 0.5, 'BRO_NEP': 0.5, 'BRO_NIE': 0.5, 'BRO_PER': 0.5, 'BRO_STT': 0.5, 'BRO_SIS': 0.5, 'BRO_BUR': 0.5, 'BRO_COL': 0.5, 'BRO_BUD': 0.5, 'BRO_MAT': 0.5,\
                     'FRI_FAT': 0.5, 'FRI_COU': 0.5, 'FRI_BRO': 0.5, 'FRI_DRI': 0.5, 'FRI_CON': 0.5, 'FRI_MEN': 0.5, 'FRI_HUM': 0.5, 'FRI_AGE': 0.5, 'FRI_ASC': 0.5, 'FRI_NEP': 0.5, 'FRI_NIE': 0.5, 'FRI_PER': 0.5, 'FRI_STT': 0.5, 'FRI_SIS': 0.5, 'FRI_BUR': 0.5, 'FRI_COL': 0.5, 'FRI_BUD': 0.5, 'FRI_MAT': 0.5,\
                     'DRI_FAT': 0.5, 'DRI_COU': 0.5, 'DRI_BRO': 0.5, 'DRI_FRI': 0.5, 'DRI_CON': 0.5, 'DRI_MEN': 0.5, 'DRI_HUM': 0.5, 'DRI_AGE': 0.5, 'DRI_ASC': 0.5, 'DRI_NEP': 0.5, 'DRI_NIE': 0.5, 'DRI_PER': 0.5, 'DRI_STT': 0.5, 'DRI_SIS': 0.5, 'DRI_BUR': 0.5, 'DRI_COL': 0.5, 'DRI_BUD': 0.5, 'DRI_MAT': 0.5,\
                     'CON_FAT': 0.5, 'CON_COU': 0.5, 'CON_BRO': 0.5, 'CON_FRI': 0.5, 'CON_DRI': 0.5, 'CON_MEN': 0.5, 'CON_HUM': 0.5, 'CON_AGE': 0.5, 'CON_ASC': 0.5, 'CON_NEP': 0.5, 'CON_NIE': 0.5, 'CON_PER': 0.5, 'CON_STT': 0.5, 'CON_SIS': 0.5, 'CON_BUR': 0.5, 'CON_COL': 0.5, 'CON_BUD': 0.5, 'CON_MAT': 0.5,\
                     'ASC_FAT': 0.5, 'ASC_COU': 0.5, 'ASC_BRO': 0.5, 'ASC_FRI': 0.5, 'ASC_DRI': 0.5, 'ASC_MEN': 0.5, 'ASC_HUM': 0.5, 'ASC_AGE': 0.5, 'ASC_CON': 0.5, 'ASC_NEP': 0.5, 'ASC_NIE': 0.5, 'ASC_PER': 0.5, 'ASC_STT': 0.5, 'ASC_SIS': 0.5, 'ASC_BUR': 0.5, 'ASC_COL': 0.5, 'ASC_BUD': 0.5, 'ASC_MAT': 0.5,\
                     'NEP_FAT': 0.5, 'NEP_COU': 0.5, 'NEP_BRO': 0.5, 'NEP_FRI': 0.5, 'NEP_DRI': 0.5, 'NEP_MEN': 0.5, 'NEP_HUM': 0.5, 'NEP_AGE': 0.5, 'NEP_ASC': 0.5, 'NEP_CON': 0.5, 'NEP_NIE': 0.5, 'NEP_PER': 0.5, 'NEP_STT': 0.5, 'NEP_SIS': 0.5, 'NEP_BUR': 0.5, 'NEP_COL': 0.5, 'NEP_BUD': 0.5, 'NEP_MAT': 0.5,\
                     'NIE_FAT': 0.5, 'NIE_COU': 0.5, 'NIE_BRO': 0.5, 'NIE_FRI': 0.5, 'NIE_DRI': 0.5, 'NIE_MEN': 0.5, 'NIE_HUM': 0.5, 'NIE_AGE': 0.5, 'NIE_ASC': 0.5, 'NIE_CON': 0.5, 'NIE_NEP': 0.5, 'NIE_PER': 0.5, 'NIE_STT': 0.5, 'NIE_SIS': 0.5, 'NIE_BUR': 0.5, 'NIE_COL': 0.5, 'NIE_BUD': 0.5, 'NIE_MAT': 0.5,\
                     'MEN_FAT': 0.5, 'MEN_BRO': 0.5, 'MEN_FRI': 0.5, 'MEN_DRI': 0.5, 'MEN_CON': 0.5, 'MEN_COU': 0.5, 'MEN_HUM': 0.5, 'MEN_AGE': 0.5, 'MEN_ASC': 0.5, 'MEN_NEP': 0.5, 'MEN_NIE': 0.5, 'MEN_PER': 0.5, 'MEN_STT': 0.5, 'MEN_SIS': 0.5, 'MEN_BUR': 0.5, 'MEN_COL': 0.5, 'MEN_BUD': 0.5, 'MEN_MAT': 0.5,\
                     'PER_FAT': 0.5, 'PER_BRO': 0.5, 'PER_FRI': 0.5, 'PER_DRI': 0.5, 'PER_CON': 0.5, 'PER_COU': 0.5, 'PER_HUM': 0.5, 'PER_AGE': 0.5, 'PER_ASC': 0.5, 'PER_NEP': 0.5, 'PER_NIE': 0.5, 'PER_MEN': 0.5, 'PER_STT': 0.5, 'PER_SIS': 0.5, 'PER_BUR': 0.5, 'PER_COL': 0.5, 'PER_BUD': 0.5, 'PER_MAT': 0.5,\
                     'STT_FAT': 0.5, 'STT_BRO': 0.5, 'STT_FRI': 0.5, 'STT_DRI': 0.5, 'STT_CON': 0.5, 'STT_COU': 0.5, 'STT_HUM': 0.5, 'STT_AGE': 0.5, 'STT_ASC': 0.5, 'STT_NEP': 0.5, 'STT_NIE': 0.5, 'STT_MEN': 0.5, 'STT_PER': 0.5, 'STT_SIS': 0.5, 'STT_BUR': 0.5, 'STT_COL': 0.5, 'STT_BUD': 0.5, 'STT_MAT': 0.5,\
                     'SIS_FAT': 0.5, 'SIS_BRO': 0.5, 'SIS_FRI': 0.5, 'SIS_DRI': 0.5, 'SIS_CON': 0.5, 'SIS_COU': 0.5, 'SIS_HUM': 0.5, 'SIS_AGE': 0.5, 'SIS_ASC': 0.5, 'SIS_NEP': 0.5, 'SIS_NIE': 0.5, 'SIS_MEN': 0.5, 'SIS_PER': 0.5, 'SIS_STT': 0.5, 'SIS_BUR': 0.5, 'SIS_COL': 0.5, 'SIS_BUD': 0.5, 'SIS_MAT': 0.5,\
                     'BUR_FAT': 0.5, 'BUR_BRO': 0.5, 'BUR_FRI': 0.5, 'BUR_DRI': 0.5, 'BUR_CON': 0.5, 'BUR_COU': 0.5, 'BUR_HUM': 0.5, 'BUR_AGE': 0.5, 'BUR_ASC': 0.5, 'BUR_NEP': 0.5, 'BUR_NIE': 0.5, 'BUR_MEN': 0.5, 'BUR_PER': 0.5, 'BUR_STT': 0.5, 'BUR_SIS': 0.5, 'BUR_COL': 0.5, 'BUR_BUD': 0.5, 'BUR_MAT': 0.5,\
                     'COL_FAT': 0.5, 'COL_BRO': 0.5, 'COL_FRI': 0.5, 'COL_DRI': 0.5, 'COL_CON': 0.5, 'COL_COU': 0.5, 'COL_HUM': 0.5, 'COL_AGE': 0.5, 'COL_ASC': 0.5, 'COL_NEP': 0.5, 'COL_NIE': 0.5, 'COL_MEN': 0.5, 'COL_PER': 0.5, 'COL_STT': 0.5, 'COL_SIS': 0.5, 'COL_BUD': 0.5, 'COL_BUR': 0.5, 'COL_MAT': 0.5,\
                     'BUD_FAT': 0.5, 'BUD_BRO': 0.5, 'BUD_FRI': 0.5, 'BUD_DRI': 0.5, 'BUD_CON': 0.5, 'BUD_COU': 0.5, 'BUD_HUM': 0.5, 'BUD_AGE': 0.5, 'BUD_ASC': 0.5, 'BUD_NEP': 0.5, 'BUD_NIE': 0.5, 'BUD_MEN': 0.5, 'BUD_PER': 0.5, 'BUD_STT': 0.5, 'BUD_SIS': 0.5, 'BUD_COL': 0.5, 'BUD_BUR': 0.5, 'BUD_MAT': 0.5,\
                     'MAT_FAT': 0.5, 'MAT_BRO': 0.5, 'MAT_FRI': 0.5, 'MAT_DRI': 0.5, 'MAT_CON': 0.5, 'MAT_COU': 0.5, 'MAT_HUM': 0.5, 'MAT_AGE': 0.5, 'MAT_ASC': 0.5, 'MAT_NEP': 0.5, 'MAT_NIE': 0.5, 'MAT_MEN': 0.5, 'MAT_PER': 0.5, 'MAT_STT': 0.5, 'MAT_SIS': 0.5, 'MAT_COL': 0.5, 'MAT_BUR': 0.5, 'MAT_BUD': 0.5,\
                     'COU_COU': 0.5, 'BRO_BRO': 0.5, 'FRI_FRI': 0.5, 'DRI_DRI': 0.5, 'CON_CON': 0.5, 'MEN_MEN': 0.5, 'HUM_HUM': 0.5, 'AGE_AGE': 0.5, 'ASC_ASC': 0.5, 'NEP_NEP': 0.5, 'NIE_NIE': 0.5, 'PER_PER': 0.5, 'STT_STT': 0.5, 'SIS_SIS': 0.5, 'BUR_BUR': 0.5, 'COL_COL': 0.5, 'BUD_BUD': 0.5, 'MAT_MAT': 0.5,}


edge_trust_business = {'KIM_KIP': 0.5, 'KIM_ORP': 0.5, 'KIM_EXP': 0.5, 'KIM_CHA': 0.5, 'KIM_COR': 0.5, 'KIM_UIT': 0.5, 'KIM_HAN': 0.5, 'KIM_TRA': 0.5, 'KIM_FIN': 0.5, 'KIM_DUA': 0.5,'KIM_LEV': 0.5, 'KIM_POR': 0.5, 'KIM_STA': 0.5, 'KIM_UMA': 0.5, 'KIM_PBI': 0.5, 'KIM_VER': 0.5, 'KIM_BEV': 0.5, 'KIM_STR': 0.5,\
                     'KIP_KIM': 0.5, 'KIP_ORP': 0.5, 'KIP_EXP': 0.5, 'KIP_CHA': 0.5, 'KIP_COR': 0.5, 'KIP_UIT': 0.5, 'KIP_HAN': 0.5, 'KIP_TRA': 0.5, 'KIP_FIN': 0.5, 'KIP_DUA': 0.5, 'KIP_LEV': 0.5, 'KIP_POR': 0.5, 'KIP_STA': 0.5, 'KIP_UMA': 0.5, 'KIP_PBI': 0.5, 'KIP_VER': 0.5, 'KIP_BEV': 0.5, 'KIP_STR': 0.5,\
                     'HAN_KIM': 0.5, 'HAN_ORP': 0.5, 'HAN_EXP': 0.5, 'HAN_CHA': 0.5, 'HAN_COR': 0.5, 'HAN_UIT': 0.5, 'HAN_KIP': 0.5, 'HAN_TRA': 0.5, 'HAN_FIN': 0.5, 'HAN_DUA': 0.5, 'HAN_LEV': 0.5, 'HAN_POR': 0.5, 'HAN_STA': 0.5, 'HAN_UMA': 0.5, 'HAN_PBI': 0.5, 'HAN_VER': 0.5, 'HAN_BEV': 0.5, 'HAN_STR': 0.5,\
                     'TRA_KIM': 0.5, 'TRA_ORP': 0.5, 'TRA_EXP': 0.5, 'TRA_CHA': 0.5, 'TRA_COR': 0.5, 'TRA_UIT': 0.5, 'TRA_HAN': 0.5, 'TRA_KIP': 0.5, 'TRA_FIN': 0.5, 'TRA_DUA': 0.5, 'TRA_LEV': 0.5, 'TRA_POR': 0.5, 'TRA_STA': 0.5, 'TRA_UMA': 0.5, 'TRA_PBI': 0.5, 'TRA_VER': 0.5, 'TRA_BEV': 0.5, 'TRA_STR': 0.5,\
                     'LEV_KIM': 0.5, 'LEV_ORP': 0.5, 'LEV_EXP': 0.5, 'LEV_CHA': 0.5, 'LEV_COR': 0.5, 'LEV_UIT': 0.5, 'LEV_HAN': 0.5, 'LEV_KIP': 0.5, 'LEV_FIN': 0.5, 'LEV_DUA': 0.5, 'LEV_TRA': 0.5, 'LEV_POR': 0.5, 'LEV_STA': 0.5, 'LEV_UMA': 0.5, 'LEV_PBI': 0.5, 'LEV_VER': 0.5, 'LEV_BEV': 0.5, 'LEV_STR': 0.5,\
                     'ORP_KIM': 0.5, 'ORP_KIP': 0.5, 'ORP_EXP': 0.5, 'ORP_CHA': 0.5, 'ORP_COR': 0.5, 'ORP_UIT': 0.5, 'ORP_HAN': 0.5, 'ORP_TRA': 0.5, 'ORP_FIN': 0.5, 'ORP_DUA': 0.5, 'ORP_LEV': 0.5, 'ORP_POR': 0.5, 'ORP_STA': 0.5, 'ORP_UMA': 0.5, 'ORP_PBI': 0.5, 'ORP_VER': 0.5, 'ORP_BEV': 0.5, 'ORP_STR': 0.5,\
                     'EXP_KIM': 0.5, 'EXP_KIP': 0.5, 'EXP_ORP': 0.5, 'EXP_CHA': 0.5, 'EXP_COR': 0.5, 'EXP_UIT': 0.5, 'EXP_HAN': 0.5, 'EXP_TRA': 0.5, 'EXP_FIN': 0.5, 'EXP_DUA': 0.5, 'EXP_LEV': 0.5, 'EXP_POR': 0.5, 'EXP_STA': 0.5, 'EXP_UMA': 0.5, 'EXP_PBI': 0.5, 'EXP_VER': 0.5, 'EXP_BEV': 0.5, 'EXP_STR': 0.5,\
                     'CHA_KIM': 0.5, 'CHA_KIP': 0.5, 'CHA_ORP': 0.5, 'CHA_EXP': 0.5, 'CHA_COR': 0.5, 'CHA_UIT': 0.5, 'CHA_HAN': 0.5, 'CHA_TRA': 0.5, 'CHA_FIN': 0.5, 'CHA_DUA': 0.5, 'CHA_LEV': 0.5, 'CHA_POR': 0.5, 'CHA_STA': 0.5, 'CHA_UMA': 0.5, 'CHA_PBI': 0.5, 'CHA_VER': 0.5, 'CHA_BEV': 0.5, 'CHA_STR': 0.5,\
                     'COR_KIM': 0.5, 'COR_KIP': 0.5, 'COR_ORP': 0.5, 'COR_EXP': 0.5, 'COR_CHA': 0.5, 'COR_UIT': 0.5, 'COR_HAN': 0.5, 'COR_TRA': 0.5, 'COR_FIN': 0.5, 'COR_DUA': 0.5, 'COR_LEV': 0.5, 'COR_POR': 0.5, 'COR_STA': 0.5, 'COR_UMA': 0.5, 'COR_PBI': 0.5, 'COR_VER': 0.5, 'COR_BEV': 0.5, 'COR_STR': 0.5,\
                     'FIN_KIM': 0.5, 'FIN_KIP': 0.5, 'FIN_ORP': 0.5, 'FIN_EXP': 0.5, 'FIN_CHA': 0.5, 'FIN_UIT': 0.5, 'FIN_HAN': 0.5, 'FIN_TRA': 0.5, 'FIN_COR': 0.5, 'FIN_DUA': 0.5, 'FIN_LEV': 0.5, 'FIN_POR': 0.5, 'FIN_STA': 0.5, 'FIN_UMA': 0.5, 'FIN_PBI': 0.5, 'FIN_VER': 0.5, 'FIN_BEV': 0.5, 'FIN_STR': 0.5,\
                     'DUA_KIM': 0.5, 'DUA_KIP': 0.5, 'DUA_ORP': 0.5, 'DUA_EXP': 0.5, 'DUA_CHA': 0.5, 'DUA_UIT': 0.5, 'DUA_HAN': 0.5, 'DUA_TRA': 0.5, 'DUA_FIN': 0.5, 'DUA_COR': 0.5, 'DUA_LEV': 0.5, 'DUA_POR': 0.5, 'DUA_STA': 0.5, 'DUA_UMA': 0.5, 'DUA_PBI': 0.5, 'DUA_VER': 0.5, 'DUA_BEV': 0.5, 'DUA_STR': 0.5,\
                     'POR_KIM': 0.5, 'POR_ORP': 0.5, 'POR_EXP': 0.5, 'POR_CHA': 0.5, 'POR_COR': 0.5, 'POR_UIT': 0.5, 'POR_HAN': 0.5, 'POR_TRA': 0.5, 'POR_FIN': 0.5, 'POR_DUA': 0.5, 'POR_LEV': 0.5, 'POR_KIP': 0.5, 'POR_STA': 0.5, 'POR_UMA': 0.5, 'POR_PBI': 0.5, 'POR_VER': 0.5, 'POR_BEV': 0.5, 'POR_STR': 0.5,\
                     'UIT_KIM': 0.5, 'UIT_KIP': 0.5, 'UIT_ORP': 0.5, 'UIT_EXP': 0.5, 'UIT_CHA': 0.5, 'UIT_COR': 0.5, 'UIT_HAN': 0.5, 'UIT_TRA': 0.5, 'UIT_FIN': 0.5, 'UIT_DUA': 0.5, 'UIT_LEV': 0.5, 'UIT_POR': 0.5, 'UIT_STA': 0.5, 'UIT_UMA': 0.5, 'UIT_PBI': 0.5, 'UIT_VER': 0.5, 'UIT_BEV': 0.5, 'UIT_STR': 0.5,\
                     'UMA_KIM': 0.5, 'UMA_KIP': 0.5, 'UMA_ORP': 0.5, 'UMA_EXP': 0.5, 'UMA_CHA': 0.5, 'UMA_COR': 0.5, 'UMA_HAN': 0.5, 'UMA_TRA': 0.5, 'UMA_FIN': 0.5, 'UMA_DUA': 0.5, 'UMA_LEV': 0.5, 'UMA_POR': 0.5, 'UMA_UIT': 0.5, 'UMA_STA': 0.5, 'UMA_PBI': 0.5, 'UMA_VER': 0.5, 'UMA_BEV': 0.5, 'UMA_STR': 0.5,\
                     'STA_KIM': 0.5, 'STA_KIP': 0.5, 'STA_ORP': 0.5, 'STA_EXP': 0.5, 'STA_CHA': 0.5, 'STA_COR': 0.5, 'STA_HAN': 0.5, 'STA_TRA': 0.5, 'STA_FIN': 0.5, 'STA_DUA': 0.5, 'STA_LEV': 0.5, 'STA_POR': 0.5, 'STA_UIT': 0.5, 'STA_UMA': 0.5, 'STA_PBI': 0.5, 'STA_VER': 0.5, 'STA_BEV': 0.5, 'STA_STR': 0.5,\
                     'PBI_KIM': 0.5, 'PBI_KIP': 0.5, 'PBI_ORP': 0.5, 'PBI_EXP': 0.5, 'PBI_CHA': 0.5, 'PBI_COR': 0.5, 'PBI_HAN': 0.5, 'PBI_TRA': 0.5, 'PBI_FIN': 0.5, 'PBI_DUA': 0.5, 'PBI_LEV': 0.5, 'PBI_POR': 0.5, 'PBI_UIT': 0.5, 'PBI_UMA': 0.5, 'PBI_STA': 0.5, 'PBI_VER': 0.5, 'PBI_BEV': 0.5, 'PBI_STR': 0.5,\
                     'VER_KIM': 0.5, 'VER_KIP': 0.5, 'VER_ORP': 0.5, 'VER_EXP': 0.5, 'VER_CHA': 0.5, 'VER_COR': 0.5, 'VER_HAN': 0.5, 'VER_TRA': 0.5, 'VER_FIN': 0.5, 'VER_DUA': 0.5, 'VER_LEV': 0.5, 'VER_POR': 0.5, 'VER_UIT': 0.5, 'VER_UMA': 0.5, 'VER_PBI': 0.5, 'VER_STA': 0.5, 'VER_BEV': 0.5, 'VER_STR': 0.5,\
                     'BEV_KIM': 0.5, 'BEV_KIP': 0.5, 'BEV_ORP': 0.5, 'BEV_EXP': 0.5, 'BEV_CHA': 0.5, 'BEV_COR': 0.5, 'BEV_HAN': 0.5, 'BEV_TRA': 0.5, 'BEV_FIN': 0.5, 'BEV_DUA': 0.5, 'BEV_LEV': 0.5, 'BEV_POR': 0.5, 'BEV_UIT': 0.5, 'BEV_UMA': 0.5, 'BEV_STA': 0.5, 'BEV_VER': 0.5, 'BEV_PBI': 0.5, 'BEV_STR': 0.5,\
                     'STR_KIM': 0.5, 'STR_KIP': 0.5, 'STR_ORP': 0.5, 'STR_EXP': 0.5, 'STR_CHA': 0.5, 'STR_COR': 0.5, 'STR_HAN': 0.5, 'STR_TRA': 0.5, 'STR_FIN': 0.5, 'STR_DUA': 0.5, 'STR_LEV': 0.5, 'STR_POR': 0.5, 'STR_UIT': 0.5, 'STR_UMA': 0.5, 'STR_STA': 0.5, 'STR_VER': 0.5, 'STR_PBI': 0.5, 'STR_BEV': 0.5,\
                     'KIP_KIP': 0.5, 'ORP_ORP': 0.5, 'EXP_EXP': 0.5, 'CHA_CHA': 0.5, 'COR_COR': 0.5, 'UIT_UIT': 0.5, 'HAN_HAN': 0.5, 'TRA_TRA': 0.5, 'FIN_FIN': 0.5, 'DUA_DUA': 0.5, 'LEV_LEV': 0.5, 'POR_POR': 0.5, 'STA_STA': 0.5, 'UMA_UMA': 0.5, 'PBI_PBI': 0.5, 'VER_VER': 0.5, 'BEV_BEV': 0.5, 'STR_STR': 0.5,}


edge_violence_business = {'KIM_KIP': 0.5, 'KIM_ORP': 0.5, 'KIM_EXP': 0.5, 'KIM_CHA': 0.5, 'KIM_COR': 0.5, 'KIM_UIT': 0.5, 'KIM_HAN': 0.5, 'KIM_TRA': 0.5, 'KIM_FIN': 0.5, 'KIM_DUA': 0.5,'KIM_LEV': 0.5, 'KIM_POR': 0.5, 'KIM_STA': 0.5, 'KIM_UMA': 0.5, 'KIM_PBI': 0.5, 'KIM_VER': 0.5, 'KIM_BEV': 0.5, 'KIM_STR': 0.5,\
                     'KIP_KIM': 0.5, 'KIP_ORP': 0.5, 'KIP_EXP': 0.5, 'KIP_CHA': 0.5, 'KIP_COR': 0.5, 'KIP_UIT': 0.5, 'KIP_HAN': 0.5, 'KIP_TRA': 0.5, 'KIP_FIN': 0.5, 'KIP_DUA': 0.5, 'KIP_LEV': 0.5, 'KIP_POR': 0.5, 'KIP_STA': 0.5, 'KIP_UMA': 0.5, 'KIP_PBI': 0.5, 'KIP_VER': 0.5, 'KIP_BEV': 0.5, 'KIP_STR': 0.5,\
                     'HAN_KIM': 0.5, 'HAN_ORP': 0.5, 'HAN_EXP': 0.5, 'HAN_CHA': 0.5, 'HAN_COR': 0.5, 'HAN_UIT': 0.5, 'HAN_KIP': 0.5, 'HAN_TRA': 0.5, 'HAN_FIN': 0.5, 'HAN_DUA': 0.5, 'HAN_LEV': 0.5, 'HAN_POR': 0.5, 'HAN_STA': 0.5, 'HAN_UMA': 0.5, 'HAN_PBI': 0.5, 'HAN_VER': 0.5, 'HAN_BEV': 0.5, 'HAN_STR': 0.5,\
                     'TRA_KIM': 0.5, 'TRA_ORP': 0.5, 'TRA_EXP': 0.5, 'TRA_CHA': 0.5, 'TRA_COR': 0.5, 'TRA_UIT': 0.5, 'TRA_HAN': 0.5, 'TRA_KIP': 0.5, 'TRA_FIN': 0.5, 'TRA_DUA': 0.5, 'TRA_LEV': 0.5, 'TRA_POR': 0.5, 'TRA_STA': 0.5, 'TRA_UMA': 0.5, 'TRA_PBI': 0.5, 'TRA_VER': 0.5, 'TRA_BEV': 0.5, 'TRA_STR': 0.5,\
                     'LEV_KIM': 0.5, 'LEV_ORP': 0.5, 'LEV_EXP': 0.5, 'LEV_CHA': 0.5, 'LEV_COR': 0.5, 'LEV_UIT': 0.5, 'LEV_HAN': 0.5, 'LEV_KIP': 0.5, 'LEV_FIN': 0.5, 'LEV_DUA': 0.5, 'LEV_TRA': 0.5, 'LEV_POR': 0.5, 'LEV_STA': 0.5, 'LEV_UMA': 0.5, 'LEV_PBI': 0.5, 'LEV_VER': 0.5, 'LEV_BEV': 0.5, 'LEV_STR': 0.5,\
                     'ORP_KIM': 0.5, 'ORP_KIP': 0.5, 'ORP_EXP': 0.5, 'ORP_CHA': 0.5, 'ORP_COR': 0.5, 'ORP_UIT': 0.5, 'ORP_HAN': 0.5, 'ORP_TRA': 0.5, 'ORP_FIN': 0.5, 'ORP_DUA': 0.5, 'ORP_LEV': 0.5, 'ORP_POR': 0.5, 'ORP_STA': 0.5, 'ORP_UMA': 0.5, 'ORP_PBI': 0.5, 'ORP_VER': 0.5, 'ORP_BEV': 0.5, 'ORP_STR': 0.5,\
                     'EXP_KIM': 0.5, 'EXP_KIP': 0.5, 'EXP_ORP': 0.5, 'EXP_CHA': 0.5, 'EXP_COR': 0.5, 'EXP_UIT': 0.5, 'EXP_HAN': 0.5, 'EXP_TRA': 0.5, 'EXP_FIN': 0.5, 'EXP_DUA': 0.5, 'EXP_LEV': 0.5, 'EXP_POR': 0.5, 'EXP_STA': 0.5, 'EXP_UMA': 0.5, 'EXP_PBI': 0.5, 'EXP_VER': 0.5, 'EXP_BEV': 0.5, 'EXP_STR': 0.5,\
                     'CHA_KIM': 0.5, 'CHA_KIP': 0.5, 'CHA_ORP': 0.5, 'CHA_EXP': 0.5, 'CHA_COR': 0.5, 'CHA_UIT': 0.5, 'CHA_HAN': 0.5, 'CHA_TRA': 0.5, 'CHA_FIN': 0.5, 'CHA_DUA': 0.5, 'CHA_LEV': 0.5, 'CHA_POR': 0.5, 'CHA_STA': 0.5, 'CHA_UMA': 0.5, 'CHA_PBI': 0.5, 'CHA_VER': 0.5, 'CHA_BEV': 0.5, 'CHA_STR': 0.5,\
                     'COR_KIM': 0.5, 'COR_KIP': 0.5, 'COR_ORP': 0.5, 'COR_EXP': 0.5, 'COR_CHA': 0.5, 'COR_UIT': 0.5, 'COR_HAN': 0.5, 'COR_TRA': 0.5, 'COR_FIN': 0.5, 'COR_DUA': 0.5, 'COR_LEV': 0.5, 'COR_POR': 0.5, 'COR_STA': 0.5, 'COR_UMA': 0.5, 'COR_PBI': 0.5, 'COR_VER': 0.5, 'COR_BEV': 0.5, 'COR_STR': 0.5,\
                     'FIN_KIM': 0.5, 'FIN_KIP': 0.5, 'FIN_ORP': 0.5, 'FIN_EXP': 0.5, 'FIN_CHA': 0.5, 'FIN_UIT': 0.5, 'FIN_HAN': 0.5, 'FIN_TRA': 0.5, 'FIN_COR': 0.5, 'FIN_DUA': 0.5, 'FIN_LEV': 0.5, 'FIN_POR': 0.5, 'FIN_STA': 0.5, 'FIN_UMA': 0.5, 'FIN_PBI': 0.5, 'FIN_VER': 0.5, 'FIN_BEV': 0.5, 'FIN_STR': 0.5,\
                     'DUA_KIM': 0.5, 'DUA_KIP': 0.5, 'DUA_ORP': 0.5, 'DUA_EXP': 0.5, 'DUA_CHA': 0.5, 'DUA_UIT': 0.5, 'DUA_HAN': 0.5, 'DUA_TRA': 0.5, 'DUA_FIN': 0.5, 'DUA_COR': 0.5, 'DUA_LEV': 0.5, 'DUA_POR': 0.5, 'DUA_STA': 0.5, 'DUA_UMA': 0.5, 'DUA_PBI': 0.5, 'DUA_VER': 0.5, 'DUA_BEV': 0.5, 'DUA_STR': 0.5,\
                     'POR_KIM': 0.5, 'POR_ORP': 0.5, 'POR_EXP': 0.5, 'POR_CHA': 0.5, 'POR_COR': 0.5, 'POR_UIT': 0.5, 'POR_HAN': 0.5, 'POR_TRA': 0.5, 'POR_FIN': 0.5, 'POR_DUA': 0.5, 'POR_LEV': 0.5, 'POR_KIP': 0.5, 'POR_STA': 0.5, 'POR_UMA': 0.5, 'POR_PBI': 0.5, 'POR_VER': 0.5, 'POR_BEV': 0.5, 'POR_STR': 0.5,\
                     'UIT_KIM': 0.5, 'UIT_KIP': 0.5, 'UIT_ORP': 0.5, 'UIT_EXP': 0.5, 'UIT_CHA': 0.5, 'UIT_COR': 0.5, 'UIT_HAN': 0.5, 'UIT_TRA': 0.5, 'UIT_FIN': 0.5, 'UIT_DUA': 0.5, 'UIT_LEV': 0.5, 'UIT_POR': 0.5, 'UIT_STA': 0.5, 'UIT_UMA': 0.5, 'UIT_PBI': 0.5, 'UIT_VER': 0.5, 'UIT_BEV': 0.5, 'UIT_STR': 0.5,\
                     'UMA_KIM': 0.5, 'UMA_KIP': 0.5, 'UMA_ORP': 0.5, 'UMA_EXP': 0.5, 'UMA_CHA': 0.5, 'UMA_COR': 0.5, 'UMA_HAN': 0.5, 'UMA_TRA': 0.5, 'UMA_FIN': 0.5, 'UMA_DUA': 0.5, 'UMA_LEV': 0.5, 'UMA_POR': 0.5, 'UMA_UIT': 0.5, 'UMA_STA': 0.5, 'UMA_PBI': 0.5, 'UMA_VER': 0.5, 'UMA_BEV': 0.5, 'UMA_STR': 0.5,\
                     'STA_KIM': 0.5, 'STA_KIP': 0.5, 'STA_ORP': 0.5, 'STA_EXP': 0.5, 'STA_CHA': 0.5, 'STA_COR': 0.5, 'STA_HAN': 0.5, 'STA_TRA': 0.5, 'STA_FIN': 0.5, 'STA_DUA': 0.5, 'STA_LEV': 0.5, 'STA_POR': 0.5, 'STA_UIT': 0.5, 'STA_UMA': 0.5, 'STA_PBI': 0.5, 'STA_VER': 0.5, 'STA_BEV': 0.5, 'STA_STR': 0.5,\
                     'PBI_KIM': 0.5, 'PBI_KIP': 0.5, 'PBI_ORP': 0.5, 'PBI_EXP': 0.5, 'PBI_CHA': 0.5, 'PBI_COR': 0.5, 'PBI_HAN': 0.5, 'PBI_TRA': 0.5, 'PBI_FIN': 0.5, 'PBI_DUA': 0.5, 'PBI_LEV': 0.5, 'PBI_POR': 0.5, 'PBI_UIT': 0.5, 'PBI_UMA': 0.5, 'PBI_STA': 0.5, 'PBI_VER': 0.5, 'PBI_BEV': 0.5, 'PBI_STR': 0.5,\
                     'VER_KIM': 0.5, 'VER_KIP': 0.5, 'VER_ORP': 0.5, 'VER_EXP': 0.5, 'VER_CHA': 0.5, 'VER_COR': 0.5, 'VER_HAN': 0.5, 'VER_TRA': 0.5, 'VER_FIN': 0.5, 'VER_DUA': 0.5, 'VER_LEV': 0.5, 'VER_POR': 0.5, 'VER_UIT': 0.5, 'VER_UMA': 0.5, 'VER_PBI': 0.5, 'VER_STA': 0.5, 'VER_BEV': 0.5, 'VER_STR': 0.5,\
                     'BEV_KIM': 0.5, 'BEV_KIP': 0.5, 'BEV_ORP': 0.5, 'BEV_EXP': 0.5, 'BEV_CHA': 0.5, 'BEV_COR': 0.5, 'BEV_HAN': 0.5, 'BEV_TRA': 0.5, 'BEV_FIN': 0.5, 'BEV_DUA': 0.5, 'BEV_LEV': 0.5, 'BEV_POR': 0.5, 'BEV_UIT': 0.5, 'BEV_UMA': 0.5, 'BEV_STA': 0.5, 'BEV_VER': 0.5, 'BEV_PBI': 0.5, 'BEV_STR': 0.5,\
                     'STR_KIM': 0.5, 'STR_KIP': 0.5, 'STR_ORP': 0.5, 'STR_EXP': 0.5, 'STR_CHA': 0.5, 'STR_COR': 0.5, 'STR_HAN': 0.5, 'STR_TRA': 0.5, 'STR_FIN': 0.5, 'STR_DUA': 0.5, 'STR_LEV': 0.5, 'STR_POR': 0.5, 'STR_UIT': 0.5, 'STR_UMA': 0.5, 'STR_STA': 0.5, 'STR_VER': 0.5, 'STR_PBI': 0.5, 'STR_BEV': 0.5,\
                     'KIP_KIP': 0.5, 'ORP_ORP': 0.5, 'EXP_EXP': 0.5, 'CHA_CHA': 0.5, 'COR_COR': 0.5, 'UIT_UIT': 0.5, 'HAN_HAN': 0.5, 'TRA_TRA': 0.5, 'FIN_FIN': 0.5, 'DUA_DUA': 0.5, 'LEV_LEV': 0.5, 'POR_POR': 0.5, 'STA_STA': 0.5, 'UMA_UMA': 0.5, 'PBI_PBI': 0.5, 'VER_VER': 0.5, 'BEV_BEV': 0.5, 'STR_STR': 0.5,}


edge_crimecapital_business = {'KIM_KIP': 0.5, 'KIM_ORP': 0.5, 'KIM_EXP': 0.5, 'KIM_CHA': 0.5, 'KIM_COR': 0.5, 'KIM_UIT': 0.5, 'KIM_HAN': 0.5, 'KIM_TRA': 0.5, 'KIM_FIN': 0.5, 'KIM_DUA': 0.5,'KIM_LEV': 0.5, 'KIM_POR': 0.5, 'KIM_STA': 0.5, 'KIM_UMA': 0.5, 'KIM_PBI': 0.5, 'KIM_VER': 0.5, 'KIM_BEV': 0.5, 'KIM_STR': 0.5,\
                     'KIP_KIM': 0.5, 'KIP_ORP': 0.5, 'KIP_EXP': 0.5, 'KIP_CHA': 0.5, 'KIP_COR': 0.5, 'KIP_UIT': 0.5, 'KIP_HAN': 0.5, 'KIP_TRA': 0.5, 'KIP_FIN': 0.5, 'KIP_DUA': 0.5, 'KIP_LEV': 0.5, 'KIP_POR': 0.5, 'KIP_STA': 0.5, 'KIP_UMA': 0.5, 'KIP_PBI': 0.5, 'KIP_VER': 0.5, 'KIP_BEV': 0.5, 'KIP_STR': 0.5,\
                     'HAN_KIM': 0.5, 'HAN_ORP': 0.5, 'HAN_EXP': 0.5, 'HAN_CHA': 0.5, 'HAN_COR': 0.5, 'HAN_UIT': 0.5, 'HAN_KIP': 0.5, 'HAN_TRA': 0.5, 'HAN_FIN': 0.5, 'HAN_DUA': 0.5, 'HAN_LEV': 0.5, 'HAN_POR': 0.5, 'HAN_STA': 0.5, 'HAN_UMA': 0.5, 'HAN_PBI': 0.5, 'HAN_VER': 0.5, 'HAN_BEV': 0.5, 'HAN_STR': 0.5,\
                     'TRA_KIM': 0.5, 'TRA_ORP': 0.5, 'TRA_EXP': 0.5, 'TRA_CHA': 0.5, 'TRA_COR': 0.5, 'TRA_UIT': 0.5, 'TRA_HAN': 0.5, 'TRA_KIP': 0.5, 'TRA_FIN': 0.5, 'TRA_DUA': 0.5, 'TRA_LEV': 0.5, 'TRA_POR': 0.5, 'TRA_STA': 0.5, 'TRA_UMA': 0.5, 'TRA_PBI': 0.5, 'TRA_VER': 0.5, 'TRA_BEV': 0.5, 'TRA_STR': 0.5,\
                     'LEV_KIM': 0.5, 'LEV_ORP': 0.5, 'LEV_EXP': 0.5, 'LEV_CHA': 0.5, 'LEV_COR': 0.5, 'LEV_UIT': 0.5, 'LEV_HAN': 0.5, 'LEV_KIP': 0.5, 'LEV_FIN': 0.5, 'LEV_DUA': 0.5, 'LEV_TRA': 0.5, 'LEV_POR': 0.5, 'LEV_STA': 0.5, 'LEV_UMA': 0.5, 'LEV_PBI': 0.5, 'LEV_VER': 0.5, 'LEV_BEV': 0.5, 'LEV_STR': 0.5,\
                     'ORP_KIM': 0.5, 'ORP_KIP': 0.5, 'ORP_EXP': 0.5, 'ORP_CHA': 0.5, 'ORP_COR': 0.5, 'ORP_UIT': 0.5, 'ORP_HAN': 0.5, 'ORP_TRA': 0.5, 'ORP_FIN': 0.5, 'ORP_DUA': 0.5, 'ORP_LEV': 0.5, 'ORP_POR': 0.5, 'ORP_STA': 0.5, 'ORP_UMA': 0.5, 'ORP_PBI': 0.5, 'ORP_VER': 0.5, 'ORP_BEV': 0.5, 'ORP_STR': 0.5,\
                     'EXP_KIM': 0.5, 'EXP_KIP': 0.5, 'EXP_ORP': 0.5, 'EXP_CHA': 0.5, 'EXP_COR': 0.5, 'EXP_UIT': 0.5, 'EXP_HAN': 0.5, 'EXP_TRA': 0.5, 'EXP_FIN': 0.5, 'EXP_DUA': 0.5, 'EXP_LEV': 0.5, 'EXP_POR': 0.5, 'EXP_STA': 0.5, 'EXP_UMA': 0.5, 'EXP_PBI': 0.5, 'EXP_VER': 0.5, 'EXP_BEV': 0.5, 'EXP_STR': 0.5,\
                     'CHA_KIM': 0.5, 'CHA_KIP': 0.5, 'CHA_ORP': 0.5, 'CHA_EXP': 0.5, 'CHA_COR': 0.5, 'CHA_UIT': 0.5, 'CHA_HAN': 0.5, 'CHA_TRA': 0.5, 'CHA_FIN': 0.5, 'CHA_DUA': 0.5, 'CHA_LEV': 0.5, 'CHA_POR': 0.5, 'CHA_STA': 0.5, 'CHA_UMA': 0.5, 'CHA_PBI': 0.5, 'CHA_VER': 0.5, 'CHA_BEV': 0.5, 'CHA_STR': 0.5,\
                     'COR_KIM': 0.5, 'COR_KIP': 0.5, 'COR_ORP': 0.5, 'COR_EXP': 0.5, 'COR_CHA': 0.5, 'COR_UIT': 0.5, 'COR_HAN': 0.5, 'COR_TRA': 0.5, 'COR_FIN': 0.5, 'COR_DUA': 0.5, 'COR_LEV': 0.5, 'COR_POR': 0.5, 'COR_STA': 0.5, 'COR_UMA': 0.5, 'COR_PBI': 0.5, 'COR_VER': 0.5, 'COR_BEV': 0.5, 'COR_STR': 0.5,\
                     'FIN_KIM': 0.5, 'FIN_KIP': 0.5, 'FIN_ORP': 0.5, 'FIN_EXP': 0.5, 'FIN_CHA': 0.5, 'FIN_UIT': 0.5, 'FIN_HAN': 0.5, 'FIN_TRA': 0.5, 'FIN_COR': 0.5, 'FIN_DUA': 0.5, 'FIN_LEV': 0.5, 'FIN_POR': 0.5, 'FIN_STA': 0.5, 'FIN_UMA': 0.5, 'FIN_PBI': 0.5, 'FIN_VER': 0.5, 'FIN_BEV': 0.5, 'FIN_STR': 0.5,\
                     'DUA_KIM': 0.5, 'DUA_KIP': 0.5, 'DUA_ORP': 0.5, 'DUA_EXP': 0.5, 'DUA_CHA': 0.5, 'DUA_UIT': 0.5, 'DUA_HAN': 0.5, 'DUA_TRA': 0.5, 'DUA_FIN': 0.5, 'DUA_COR': 0.5, 'DUA_LEV': 0.5, 'DUA_POR': 0.5, 'DUA_STA': 0.5, 'DUA_UMA': 0.5, 'DUA_PBI': 0.5, 'DUA_VER': 0.5, 'DUA_BEV': 0.5, 'DUA_STR': 0.5,\
                     'POR_KIM': 0.5, 'POR_ORP': 0.5, 'POR_EXP': 0.5, 'POR_CHA': 0.5, 'POR_COR': 0.5, 'POR_UIT': 0.5, 'POR_HAN': 0.5, 'POR_TRA': 0.5, 'POR_FIN': 0.5, 'POR_DUA': 0.5, 'POR_LEV': 0.5, 'POR_KIP': 0.5, 'POR_STA': 0.5, 'POR_UMA': 0.5, 'POR_PBI': 0.5, 'POR_VER': 0.5, 'POR_BEV': 0.5, 'POR_STR': 0.5,\
                     'UIT_KIM': 0.5, 'UIT_KIP': 0.5, 'UIT_ORP': 0.5, 'UIT_EXP': 0.5, 'UIT_CHA': 0.5, 'UIT_COR': 0.5, 'UIT_HAN': 0.5, 'UIT_TRA': 0.5, 'UIT_FIN': 0.5, 'UIT_DUA': 0.5, 'UIT_LEV': 0.5, 'UIT_POR': 0.5, 'UIT_STA': 0.5, 'UIT_UMA': 0.5, 'UIT_PBI': 0.5, 'UIT_VER': 0.5, 'UIT_BEV': 0.5, 'UIT_STR': 0.5,\
                     'UMA_KIM': 0.5, 'UMA_KIP': 0.5, 'UMA_ORP': 0.5, 'UMA_EXP': 0.5, 'UMA_CHA': 0.5, 'UMA_COR': 0.5, 'UMA_HAN': 0.5, 'UMA_TRA': 0.5, 'UMA_FIN': 0.5, 'UMA_DUA': 0.5, 'UMA_LEV': 0.5, 'UMA_POR': 0.5, 'UMA_UIT': 0.5, 'UMA_STA': 0.5, 'UMA_PBI': 0.5, 'UMA_VER': 0.5, 'UMA_BEV': 0.5, 'UMA_STR': 0.5,\
                     'STA_KIM': 0.5, 'STA_KIP': 0.5, 'STA_ORP': 0.5, 'STA_EXP': 0.5, 'STA_CHA': 0.5, 'STA_COR': 0.5, 'STA_HAN': 0.5, 'STA_TRA': 0.5, 'STA_FIN': 0.5, 'STA_DUA': 0.5, 'STA_LEV': 0.5, 'STA_POR': 0.5, 'STA_UIT': 0.5, 'STA_UMA': 0.5, 'STA_PBI': 0.5, 'STA_VER': 0.5, 'STA_BEV': 0.5, 'STA_STR': 0.5,\
                     'PBI_KIM': 0.5, 'PBI_KIP': 0.5, 'PBI_ORP': 0.5, 'PBI_EXP': 0.5, 'PBI_CHA': 0.5, 'PBI_COR': 0.5, 'PBI_HAN': 0.5, 'PBI_TRA': 0.5, 'PBI_FIN': 0.5, 'PBI_DUA': 0.5, 'PBI_LEV': 0.5, 'PBI_POR': 0.5, 'PBI_UIT': 0.5, 'PBI_UMA': 0.5, 'PBI_STA': 0.5, 'PBI_VER': 0.5, 'PBI_BEV': 0.5, 'PBI_STR': 0.5,\
                     'VER_KIM': 0.5, 'VER_KIP': 0.5, 'VER_ORP': 0.5, 'VER_EXP': 0.5, 'VER_CHA': 0.5, 'VER_COR': 0.5, 'VER_HAN': 0.5, 'VER_TRA': 0.5, 'VER_FIN': 0.5, 'VER_DUA': 0.5, 'VER_LEV': 0.5, 'VER_POR': 0.5, 'VER_UIT': 0.5, 'VER_UMA': 0.5, 'VER_PBI': 0.5, 'VER_STA': 0.5, 'VER_BEV': 0.5, 'VER_STR': 0.5,\
                     'BEV_KIM': 0.5, 'BEV_KIP': 0.5, 'BEV_ORP': 0.5, 'BEV_EXP': 0.5, 'BEV_CHA': 0.5, 'BEV_COR': 0.5, 'BEV_HAN': 0.5, 'BEV_TRA': 0.5, 'BEV_FIN': 0.5, 'BEV_DUA': 0.5, 'BEV_LEV': 0.5, 'BEV_POR': 0.5, 'BEV_UIT': 0.5, 'BEV_UMA': 0.5, 'BEV_STA': 0.5, 'BEV_VER': 0.5, 'BEV_PBI': 0.5, 'BEV_STR': 0.5,\
                     'STR_KIM': 0.5, 'STR_KIP': 0.5, 'STR_ORP': 0.5, 'STR_EXP': 0.5, 'STR_CHA': 0.5, 'STR_COR': 0.5, 'STR_HAN': 0.5, 'STR_TRA': 0.5, 'STR_FIN': 0.5, 'STR_DUA': 0.5, 'STR_LEV': 0.5, 'STR_POR': 0.5, 'STR_UIT': 0.5, 'STR_UMA': 0.5, 'STR_STA': 0.5, 'STR_VER': 0.5, 'STR_PBI': 0.5, 'STR_BEV': 0.5,\
                     'KIP_KIP': 0.5, 'ORP_ORP': 0.5, 'EXP_EXP': 0.5, 'CHA_CHA': 0.5, 'COR_COR': 0.5, 'UIT_UIT': 0.5, 'HAN_HAN': 0.5, 'TRA_TRA': 0.5, 'FIN_FIN': 0.5, 'DUA_DUA': 0.5, 'LEV_LEV': 0.5, 'POR_POR': 0.5, 'STA_STA': 0.5, 'UMA_UMA': 0.5, 'PBI_PBI': 0.5, 'VER_VER': 0.5, 'BEV_BEV': 0.5, 'STR_STR': 0.5,}


edge_financialkracht_business = {'KIM_KIP': 0.5, 'KIM_ORP': 0.5, 'KIM_EXP': 0.5, 'KIM_CHA': 0.5, 'KIM_COR': 0.5, 'KIM_UIT': 0.5, 'KIM_HAN': 0.5, 'KIM_TRA': 0.5, 'KIM_FIN': 0.5, 'KIM_DUA': 0.5,'KIM_LEV': 0.5, 'KIM_POR': 0.5, 'KIM_STA': 0.5, 'KIM_UMA': 0.5, 'KIM_PBI': 0.5, 'KIM_VER': 0.5, 'KIM_BEV': 0.5, 'KIM_STR': 0.5,\
                     'KIP_KIM': 0.5, 'KIP_ORP': 0.5, 'KIP_EXP': 0.5, 'KIP_CHA': 0.5, 'KIP_COR': 0.5, 'KIP_UIT': 0.5, 'KIP_HAN': 0.5, 'KIP_TRA': 0.5, 'KIP_FIN': 0.5, 'KIP_DUA': 0.5, 'KIP_LEV': 0.5, 'KIP_POR': 0.5, 'KIP_STA': 0.5, 'KIP_UMA': 0.5, 'KIP_PBI': 0.5, 'KIP_VER': 0.5, 'KIP_BEV': 0.5, 'KIP_STR': 0.5,\
                     'HAN_KIM': 0.5, 'HAN_ORP': 0.5, 'HAN_EXP': 0.5, 'HAN_CHA': 0.5, 'HAN_COR': 0.5, 'HAN_UIT': 0.5, 'HAN_KIP': 0.5, 'HAN_TRA': 0.5, 'HAN_FIN': 0.5, 'HAN_DUA': 0.5, 'HAN_LEV': 0.5, 'HAN_POR': 0.5, 'HAN_STA': 0.5, 'HAN_UMA': 0.5, 'HAN_PBI': 0.5, 'HAN_VER': 0.5, 'HAN_BEV': 0.5, 'HAN_STR': 0.5,\
                     'TRA_KIM': 0.5, 'TRA_ORP': 0.5, 'TRA_EXP': 0.5, 'TRA_CHA': 0.5, 'TRA_COR': 0.5, 'TRA_UIT': 0.5, 'TRA_HAN': 0.5, 'TRA_KIP': 0.5, 'TRA_FIN': 0.5, 'TRA_DUA': 0.5, 'TRA_LEV': 0.5, 'TRA_POR': 0.5, 'TRA_STA': 0.5, 'TRA_UMA': 0.5, 'TRA_PBI': 0.5, 'TRA_VER': 0.5, 'TRA_BEV': 0.5, 'TRA_STR': 0.5,\
                     'LEV_KIM': 0.5, 'LEV_ORP': 0.5, 'LEV_EXP': 0.5, 'LEV_CHA': 0.5, 'LEV_COR': 0.5, 'LEV_UIT': 0.5, 'LEV_HAN': 0.5, 'LEV_KIP': 0.5, 'LEV_FIN': 0.5, 'LEV_DUA': 0.5, 'LEV_TRA': 0.5, 'LEV_POR': 0.5, 'LEV_STA': 0.5, 'LEV_UMA': 0.5, 'LEV_PBI': 0.5, 'LEV_VER': 0.5, 'LEV_BEV': 0.5, 'LEV_STR': 0.5,\
                     'ORP_KIM': 0.5, 'ORP_KIP': 0.5, 'ORP_EXP': 0.5, 'ORP_CHA': 0.5, 'ORP_COR': 0.5, 'ORP_UIT': 0.5, 'ORP_HAN': 0.5, 'ORP_TRA': 0.5, 'ORP_FIN': 0.5, 'ORP_DUA': 0.5, 'ORP_LEV': 0.5, 'ORP_POR': 0.5, 'ORP_STA': 0.5, 'ORP_UMA': 0.5, 'ORP_PBI': 0.5, 'ORP_VER': 0.5, 'ORP_BEV': 0.5, 'ORP_STR': 0.5,\
                     'EXP_KIM': 0.5, 'EXP_KIP': 0.5, 'EXP_ORP': 0.5, 'EXP_CHA': 0.5, 'EXP_COR': 0.5, 'EXP_UIT': 0.5, 'EXP_HAN': 0.5, 'EXP_TRA': 0.5, 'EXP_FIN': 0.5, 'EXP_DUA': 0.5, 'EXP_LEV': 0.5, 'EXP_POR': 0.5, 'EXP_STA': 0.5, 'EXP_UMA': 0.5, 'EXP_PBI': 0.5, 'EXP_VER': 0.5, 'EXP_BEV': 0.5, 'EXP_STR': 0.5,\
                     'CHA_KIM': 0.5, 'CHA_KIP': 0.5, 'CHA_ORP': 0.5, 'CHA_EXP': 0.5, 'CHA_COR': 0.5, 'CHA_UIT': 0.5, 'CHA_HAN': 0.5, 'CHA_TRA': 0.5, 'CHA_FIN': 0.5, 'CHA_DUA': 0.5, 'CHA_LEV': 0.5, 'CHA_POR': 0.5, 'CHA_STA': 0.5, 'CHA_UMA': 0.5, 'CHA_PBI': 0.5, 'CHA_VER': 0.5, 'CHA_BEV': 0.5, 'CHA_STR': 0.5,\
                     'COR_KIM': 0.5, 'COR_KIP': 0.5, 'COR_ORP': 0.5, 'COR_EXP': 0.5, 'COR_CHA': 0.5, 'COR_UIT': 0.5, 'COR_HAN': 0.5, 'COR_TRA': 0.5, 'COR_FIN': 0.5, 'COR_DUA': 0.5, 'COR_LEV': 0.5, 'COR_POR': 0.5, 'COR_STA': 0.5, 'COR_UMA': 0.5, 'COR_PBI': 0.5, 'COR_VER': 0.5, 'COR_BEV': 0.5, 'COR_STR': 0.5,\
                     'FIN_KIM': 0.5, 'FIN_KIP': 0.5, 'FIN_ORP': 0.5, 'FIN_EXP': 0.5, 'FIN_CHA': 0.5, 'FIN_UIT': 0.5, 'FIN_HAN': 0.5, 'FIN_TRA': 0.5, 'FIN_COR': 0.5, 'FIN_DUA': 0.5, 'FIN_LEV': 0.5, 'FIN_POR': 0.5, 'FIN_STA': 0.5, 'FIN_UMA': 0.5, 'FIN_PBI': 0.5, 'FIN_VER': 0.5, 'FIN_BEV': 0.5, 'FIN_STR': 0.5,\
                     'DUA_KIM': 0.5, 'DUA_KIP': 0.5, 'DUA_ORP': 0.5, 'DUA_EXP': 0.5, 'DUA_CHA': 0.5, 'DUA_UIT': 0.5, 'DUA_HAN': 0.5, 'DUA_TRA': 0.5, 'DUA_FIN': 0.5, 'DUA_COR': 0.5, 'DUA_LEV': 0.5, 'DUA_POR': 0.5, 'DUA_STA': 0.5, 'DUA_UMA': 0.5, 'DUA_PBI': 0.5, 'DUA_VER': 0.5, 'DUA_BEV': 0.5, 'DUA_STR': 0.5,\
                     'POR_KIM': 0.5, 'POR_ORP': 0.5, 'POR_EXP': 0.5, 'POR_CHA': 0.5, 'POR_COR': 0.5, 'POR_UIT': 0.5, 'POR_HAN': 0.5, 'POR_TRA': 0.5, 'POR_FIN': 0.5, 'POR_DUA': 0.5, 'POR_LEV': 0.5, 'POR_KIP': 0.5, 'POR_STA': 0.5, 'POR_UMA': 0.5, 'POR_PBI': 0.5, 'POR_VER': 0.5, 'POR_BEV': 0.5, 'POR_STR': 0.5,\
                     'UIT_KIM': 0.5, 'UIT_KIP': 0.5, 'UIT_ORP': 0.5, 'UIT_EXP': 0.5, 'UIT_CHA': 0.5, 'UIT_COR': 0.5, 'UIT_HAN': 0.5, 'UIT_TRA': 0.5, 'UIT_FIN': 0.5, 'UIT_DUA': 0.5, 'UIT_LEV': 0.5, 'UIT_POR': 0.5, 'UIT_STA': 0.5, 'UIT_UMA': 0.5, 'UIT_PBI': 0.5, 'UIT_VER': 0.5, 'UIT_BEV': 0.5, 'UIT_STR': 0.5,\
                     'UMA_KIM': 0.5, 'UMA_KIP': 0.5, 'UMA_ORP': 0.5, 'UMA_EXP': 0.5, 'UMA_CHA': 0.5, 'UMA_COR': 0.5, 'UMA_HAN': 0.5, 'UMA_TRA': 0.5, 'UMA_FIN': 0.5, 'UMA_DUA': 0.5, 'UMA_LEV': 0.5, 'UMA_POR': 0.5, 'UMA_UIT': 0.5, 'UMA_STA': 0.5, 'UMA_PBI': 0.5, 'UMA_VER': 0.5, 'UMA_BEV': 0.5, 'UMA_STR': 0.5,\
                     'STA_KIM': 0.5, 'STA_KIP': 0.5, 'STA_ORP': 0.5, 'STA_EXP': 0.5, 'STA_CHA': 0.5, 'STA_COR': 0.5, 'STA_HAN': 0.5, 'STA_TRA': 0.5, 'STA_FIN': 0.5, 'STA_DUA': 0.5, 'STA_LEV': 0.5, 'STA_POR': 0.5, 'STA_UIT': 0.5, 'STA_UMA': 0.5, 'STA_PBI': 0.5, 'STA_VER': 0.5, 'STA_BEV': 0.5, 'STA_STR': 0.5,\
                     'PBI_KIM': 0.5, 'PBI_KIP': 0.5, 'PBI_ORP': 0.5, 'PBI_EXP': 0.5, 'PBI_CHA': 0.5, 'PBI_COR': 0.5, 'PBI_HAN': 0.5, 'PBI_TRA': 0.5, 'PBI_FIN': 0.5, 'PBI_DUA': 0.5, 'PBI_LEV': 0.5, 'PBI_POR': 0.5, 'PBI_UIT': 0.5, 'PBI_UMA': 0.5, 'PBI_STA': 0.5, 'PBI_VER': 0.5, 'PBI_BEV': 0.5, 'PBI_STR': 0.5,\
                     'VER_KIM': 0.5, 'VER_KIP': 0.5, 'VER_ORP': 0.5, 'VER_EXP': 0.5, 'VER_CHA': 0.5, 'VER_COR': 0.5, 'VER_HAN': 0.5, 'VER_TRA': 0.5, 'VER_FIN': 0.5, 'VER_DUA': 0.5, 'VER_LEV': 0.5, 'VER_POR': 0.5, 'VER_UIT': 0.5, 'VER_UMA': 0.5, 'VER_PBI': 0.5, 'VER_STA': 0.5, 'VER_BEV': 0.5, 'VER_STR': 0.5,\
                     'BEV_KIM': 0.5, 'BEV_KIP': 0.5, 'BEV_ORP': 0.5, 'BEV_EXP': 0.5, 'BEV_CHA': 0.5, 'BEV_COR': 0.5, 'BEV_HAN': 0.5, 'BEV_TRA': 0.5, 'BEV_FIN': 0.5, 'BEV_DUA': 0.5, 'BEV_LEV': 0.5, 'BEV_POR': 0.5, 'BEV_UIT': 0.5, 'BEV_UMA': 0.5, 'BEV_STA': 0.5, 'BEV_VER': 0.5, 'BEV_PBI': 0.5, 'BEV_STR': 0.5,\
                     'STR_KIM': 0.5, 'STR_KIP': 0.5, 'STR_ORP': 0.5, 'STR_EXP': 0.5, 'STR_CHA': 0.5, 'STR_COR': 0.5, 'STR_HAN': 0.5, 'STR_TRA': 0.5, 'STR_FIN': 0.5, 'STR_DUA': 0.5, 'STR_LEV': 0.5, 'STR_POR': 0.5, 'STR_UIT': 0.5, 'STR_UMA': 0.5, 'STR_STA': 0.5, 'STR_VER': 0.5, 'STR_PBI': 0.5, 'STR_BEV': 0.5,\
                     'KIP_KIP': 0.5, 'ORP_ORP': 0.5, 'EXP_EXP': 0.5, 'CHA_CHA': 0.5, 'COR_COR': 0.5, 'UIT_UIT': 0.5, 'HAN_HAN': 0.5, 'TRA_TRA': 0.5, 'FIN_FIN': 0.5, 'DUA_DUA': 0.5, 'LEV_LEV': 0.5, 'POR_POR': 0.5, 'STA_STA': 0.5, 'UMA_UMA': 0.5, 'PBI_PBI': 0.5, 'VER_VER': 0.5, 'BEV_BEV': 0.5, 'STR_STR': 0.5,}


def get_violtrustcapitalfinancial(edge_ID):
    'This function returns fixed violence and trust variables for the given input edge'
    viol = edge_violence_social[edge_ID]
    trus = edge_trust_social[edge_ID]
    capital = edge_crimecapital_social[edge_ID]
    financial = edge_financialkracht_social[edge_ID]
    return viol, trus, capital, financial

def get_semirandom_violtrustcapitalfinancial(edge_ID):
    'This function returns semi-random violence and trust variables for the given input edge'
    ran_change_viol = random.uniform(-0.25, 0.25)
    ran_change_trust = random.uniform(-0.25, 0.25)
    ran_change_crimecapital = random.uniform(-0.25, 0.25)
    ran_change_financialkracht = random.uniform(-0.25, 0.25)
    viol = edge_violence_business[edge_ID] 
    trus = edge_trust_business[edge_ID] 
    capital = edge_crimecapital_business[edge_ID]
    financial = edge_financialkracht_business[edge_ID]
    final_viol = max(min((viol + ran_change_viol), 1), 0)
    final_trust = max(min((trus + ran_change_trust), 1), 0)
    final_crimecapital = max(min((capital + ran_change_crimecapital), 1), 0)
    final_financialkracht = max(min((financial + ran_change_financialkracht), 1), 0)
    return final_viol, final_trust, final_crimecapital, final_financialkracht


def get_edgeID(G, element, name_dict):
    'This function returns an edge ID for a given edge'
    role_1 = name_dict[element[0]]
    role_2 = name_dict[element[1]]
    string_1 = get_role_char(role_1)
    string_2 = get_role_char(role_2)
    return string_1 + '_' + string_2
    
def get_role_char(role):
    'This function returns an abbreviation indicating the group that the given role belongs to'
    'It is used to create edge IDs'
    'The abbreviation should always be 3-lettered, see next function'
    if 'father' in role:
        return 'FAT'
    elif 'cousin' in role:
        return 'COU'
    elif 'brother' in role:
        return 'BRO'
    elif 'friend' in role:
        return 'FRI'
    elif 'driver' in role:
        return 'DRI'
    elif 'contact' in role:
        return 'CON'
    elif 'human' in role:
        return 'HUM'
    elif 'agent' in role:
        return 'AGE'
    elif 'person' in role:
        return 'PER'
    elif 'sister' in role:
        return 'SIS'
    elif 'associate' in role:
        return 'ASC'
    elif 'nephew' in role:
        return 'NEP'
    elif 'mate' in role:
        return 'MAT'
    elif 'statue' in role:
        return 'STT'
    elif 'niece' in role:
        return 'NIE'
    elif 'buurman' in role:
        return 'BUR'
    elif 'transporteur' in role:
        return 'TRA'
    elif 'colleague' in role:
        return 'COL'
    elif 'buddy' in role:
        return 'BUD'
    elif 'kingpin_main' in role:
        return 'KIM'
    elif 'kingpin' in role:
        return 'KIP'
    elif 'orphan' in role:
        return 'ORP'
    elif 'exporteur' in role:
        return 'EXP'
    elif 'chauffeur' in role:
        return 'CHA'
    elif 'coordinator' in role:
        return 'COR'
    elif 'uithaaler' in role:
        return 'UIT'
    elif 'mens' in role:
        return 'MEN'
    elif 'uithaalmakelaar' in role:
        return 'UMA'
    elif 'handelaar' in role:
        return 'HAN'
    elif 'financeer' in role:
        return 'FIN'
    elif 'poortwachter' in role:
        return 'POR'
    elif 'duane' in role:
        return 'DUA'
    elif 'leverancier' in role:
        return 'LEV'
    elif 'stasher' in role:
        return 'STA'
    elif 'plaatserbin' in role:
        return 'PBI'
    elif 'beveiliger' in role:
        return 'BEV'
    elif 'versneijder' in role:
        return 'VER'
    elif 'stroman' in role:
        return 'STR'
    else:
        return 'NONE'
    
def change_ID(old_string, kim_num, edge_nums):
    'This function is used to rename all links of the new kingpin to an appropriate one'
    'Be aware: the lengths of the abbreviations are assumed to always be 3: if not, wrong edge IDs will be created'
    if kim_num == edge_nums[0]:
        return 'KIM' + old_string[4:7]
    elif kim_num == edge_nums[1]:
        return old_string[0:4] + 'KIM'
    else:
        return 'NONE'

# %%
def create_networks(networks, N=120):
    'Function to create the networks involved; for now, business and social'
    
    # Return list, here the created networks will be stored
    network_list = []
    
    # Create IDs for agents
    shuffled = random.sample(range(0, N), N)

    # Set roles business
    kingpin_main = shuffled[0]
    kingpin_list = shuffled[1:4]
    orphan_list = shuffled[4:16]
    exporteur_list = shuffled[16:23]
    chauffeur_list = shuffled[23:40]
    coordinator_list = shuffled[40:45]
    uithaaler_list = shuffled[45:55]
    handelaar_list = shuffled[55:60]
    transporteur_list = shuffled[60:65]
    financeer_list = shuffled[65:70]
    duane_list = shuffled[70:75]
    leverancier_list = shuffled[75:80]
    poortwachter_list = shuffled[80:85]
    stasher_list = shuffled[85:90]
    uithaalmakelaar_list = shuffled[90:95]
    plaatserbin_list = shuffled[95:100]
    beveiliger_list = shuffled[100:105]
    versneijder_list = shuffled[105:110]
    stroman_list = shuffled[110:N]
    
    # Uncomment next line if business roles are not tied to social roles.
    #shuffled = random.sample(range(0, N), N)
    
    # Set roles family/social
    father_main = shuffled[0]
    cousin_list = shuffled[1:4]
    brother_list = shuffled[4:16]
    friend_list = shuffled[16:23]
    driver_list = shuffled[23:40]
    contact_list = shuffled[40:45]
    mens_list = shuffled[45:55]
    human_list = shuffled[55:60]
    agent_list = shuffled[60:65]
    associate_list = shuffled[65:70]
    nephew_list = shuffled[70:75]
    niece_list = shuffled[75:80]
    person_list = shuffled[80:85]
    statue_list = shuffled[85:90]
    sister_list = shuffled[90:95]
    buurman_list = shuffled[95:100]
    colleague_list = shuffled[100:105]
    buddy_list = shuffled[105:110]
    mate_list = shuffled[110:N]
    
    # Create business/social role lists
    business_role_list = [kingpin_main, financeer_list, poortwachter_list, leverancier_list, versneijder_list, stroman_list, beveiliger_list, plaatserbin_list, uithaalmakelaar_list, duane_list, stasher_list, handelaar_list, transporteur_list, kingpin_list, orphan_list, exporteur_list, chauffeur_list, coordinator_list, uithaaler_list]
    family_role_list = [father_main, cousin_list, sister_list, associate_list, person_list, mate_list, colleague_list, buddy_list, buurman_list, niece_list, statue_list, nephew_list, human_list, agent_list, brother_list, friend_list, driver_list, contact_list, mens_list]
    
    
    # Make dictionaries for attributes
    business_color_dict = make_dict(business_role_list, 'color')
    family_color_dict = make_dict(family_role_list, 'color')
    business_name_dict = make_dict(business_role_list, 'business_name')
    family_name_dict = make_dict(family_role_list, 'family_name')
    business_weight_dict = make_dict(business_role_list, 'weight')
    family_weight_dict = make_dict(family_role_list, 'weight')
        
    # Create each network
    for name in networks:
        
        # Start with empty network
        G = nx.empty_graph(N)
        
        # Set names, colours and weights
        nx.set_node_attributes(G, business_name_dict, "business_name")
        nx.set_node_attributes(G, family_name_dict, "family_name")
        nx.set_node_attributes(G, business_color_dict, "business_color")
        nx.set_node_attributes(G, family_color_dict, "family_color")
        nx.set_node_attributes(G, business_weight_dict, "business_weight")
        nx.set_node_attributes(G, family_weight_dict, "family_weight")
        
        # For business network
        if name == 'business':
            
            # Add edge lists including weight and colours
            add_edge_list(G, stroman_list, G.nodes(), 0.15, 'olivedrab', 5)
            add_edge_list(G, versneijder_list, G.nodes(), 0.15, 'forestgreen', 5)
            add_edge_list(G, beveiliger_list, G.nodes(), 0.15, 'limegreen', 5)
            add_edge_list(G, plaatserbin_list, G.nodes(), 0.15, 'lightgreen', 5)
            add_edge_list(G, stasher_list, G.nodes(), 0.15, 'white', 5)
            add_edge_list(G, uithaalmakelaar_list, G.nodes(), 0, 'pink', 80)
            add_edge_list(G, poortwachter_list, G.nodes(), 0.4, 'aqua', 25)
            add_edge_list(G, leverancier_list, G.nodes(), 0.3, 'brown', 50)
            add_edge_list(G, duane_list, G.nodes(), 0.3, 'navy', 45)
            add_edge_list(G, financeer_list, G.nodes(), 0.6, 'orangered', 60)
            add_edge_list(G, transporteur_list, G.nodes(), 0.2, 'blue', 5)
            add_edge_list(G, handelaar_list, G.nodes(), 0.1, 'crimson', 10)   
            add_edge_list(G, uithaaler_list, G.nodes(), 0.1, 'lime', 20) 
            add_edge_list(G, coordinator_list, G.nodes(), 0.1, 'darkred', 30) 
            add_edge_list(G, chauffeur_list, G.nodes(), (1/6), 'green', 50) 
            add_edge_list(G, exporteur_list, G.nodes(), 0.25, 'firebrick', 70) 
            add_edge_list(G, orphan_list, G.nodes(), (1/3), 'yellow', 80, True) 
            add_edge_list(G, kingpin_list, G.nodes(), 0.25, 'orange', 100)
            add_edge_list(G, [kingpin_main], G.nodes(), 1, 'red', 100)
            
            # Assign (semi-)random values to variables and set edge IDs
            violence_dict = dict()
            trust_dict = dict()
            usefulness_dict = dict()
            crimecapital_dict = dict()
            financialkracht_dict = dict()
            edgeID_dict = dict()
            for element in G.edges():
                edge_ID = get_edgeID(G, element, business_name_dict)
                edgeID_dict[element] = edge_ID
                viol, trus, capital, financial = get_semirandom_violtrustcapitalfinancial(edge_ID)
                violence_dict[element] = viol
                trust_dict[element] = trus
                crimecapital_dict[element] = capital
                financialkracht_dict[element] = financial
                usefulness_dict[element] = random.uniform(0.3,1)
                crimecapital_dict[element] = random.uniform(0.5,1)
                financialkracht_dict[element] = random.uniform(0.2,1)
            nx.set_edge_attributes(G, violence_dict, name="edge_violence")
            nx.set_edge_attributes(G, trust_dict, name="edge_trust")
            nx.set_edge_attributes(G, usefulness_dict, name="edge_usefulness")
            nx.set_edge_attributes(G, crimecapital_dict, name="edge_crimecapital")
            nx.set_edge_attributes(G, financialkracht_dict, name="edge, financialkracht")
            nx.set_edge_attributes(G, edgeID_dict, name="edge_ID")

            # Append network for returning
            network_list.append(G)

            # Get node and edge colours for drawing
            business_values = [business_color_dict.get(node, 'k') for node in G.nodes()]
            edge_colors = nx.get_edge_attributes(G,'color').values()
            
            # Draw network
            nx.draw(G, with_labels=True, edge_color=edge_colors, node_color=business_values)
            plt.show()
            
        # For social network
        if name == 'social':
            
            # Add edge lists including weight and colours
            add_edge_list(G, mate_list, G.nodes(), 0.15, 'olivedrab', 5)
            add_edge_list(G, buddy_list, G.nodes(), 0.15, 'forestgreen', 5)
            add_edge_list(G, colleague_list, G.nodes(), 0.15, 'limegreen', 5)   
            add_edge_list(G, buurman_list, G.nodes(), 0.15, 'lightgreen', 5)
            add_edge_list(G, sister_list, G.nodes(), 0, 'pink', 80)
            add_edge_list(G, statue_list, G.nodes(), 0.15, 'white', 5)
            add_edge_list(G, person_list, G.nodes(), 0.4, 'aqua', 25)
            add_edge_list(G, niece_list, G.nodes(), 0.3, 'brown', 50)
            add_edge_list(G, nephew_list, G.nodes(), 0.3, 'navy', 45, )
            add_edge_list(G, associate_list, G.nodes(), 0.6, 'orangered', 60, ) 
            add_edge_list(G, agent_list, G.nodes(), 0.1, 'blue', 5, )
            add_edge_list(G, human_list, friend_list, 0.1, 'crimson', 10, )
            add_edge_list(G, mens_list, friend_list, 1, 'lime', 20, True) 
            add_edge_list(G, contact_list, friend_list, 1, 'green', 50, True)
            add_edge_list(G, friend_list, friend_list, 1, 'firebrick', 70, True) 
            add_edge_list(G, brother_list, friend_list, 1, 'yellow', 80, True) 
            add_edge_list(G, cousin_list, friend_list, 1, 'orange', 70, True) 
            add_edge_list(G, [father_main], G.nodes(), 1, 'red', 100, True) 
            
            # Assign values to variables and set edge IDs
            violence_dict = dict()
            trust_dict = dict()
            edgeID_dict = dict()
            for element in G.edges():
                edge_ID = get_edgeID(G, element, family_name_dict)
                edgeID_dict[element] = edge_ID
                viol, trus, capital, financial = get_violtrustcapitalfinancial(edge_ID)
                violence_dict[element] = viol
                trust_dict[element] = trus  
                crimecapital_dict[element] = capital
                financialkracht_dict[element] = financial
            nx.set_edge_attributes(G, violence_dict, name="edge_violence")
            nx.set_edge_attributes(G, trust_dict, name="edge_trust")
            nx.set_edge_attributes(G, crimecapital_dict, name="edge_crimecapital")
            nx.set_edge_attributes(G, financialkracht_dict, name="edge_financialkracht")
            nx.set_edge_attributes(G, edgeID_dict, name="edge_ID")

            # Append network for returning
            network_list.append(G)           
                
            # Get node and edge colours for drawing
            family_colors = nx.get_edge_attributes(G,'color').values()
            family_values = [family_color_dict.get(node, 'k') for node in G.nodes()]

            # Draw network
            nx.draw(G, with_labels=True, edge_color=family_colors, node_color=family_values)
            plt.show()

    return network_list

# %%
class Agents(Agent):
    'This class creates entities to represent agents in the model'
    'Each agent is directly tied to a node in the networks'
    'This class mainly stores some basic agent info that could be very useful when extending the model'
    def __init__ (self, unique_ID, model):
        # Initialise with node number as ID and random values for the variables
        super(). __init__(unique_ID, model)
        self.ID = unique_ID
        self.violence = random.uniform(0,1)
        self.trust = random.uniform(0,1)
        self.usefulness = random.uniform(0.3,1)
        self.crimecapital = random.uniform(0.5,1)
        self.financialkracht = random.uniform(0.2, 1)
        if random.uniform(0,1) < 0.9:
            self.gen = "m"
        else:
            self.gen = "f"
    
    # The step/stages functions are set up but not yet used in the model. Can be easily implemented when needed.
    def step(self):
        print('test')   
    def stage1(self):
        print('stage1')    
    def stage2(self):
        print('stage2')     
    def stage3(self):
        print('stage3')    
    def stage4(self):
        print('stage4')

# %%
class ReplacementModel(Model):
    'This class is the working machine of the model'
    'More detailed function specifics can be found at each corresponding function'
    
    def __init__ (self, phase='start'):
        'This is the initialisation function: it is only called once, namely when a new model is created'
        'Each time it initialises, it creates 2 random networks and stores the relevant information'
        'This function initialises in the starting phase automatically, however one could manually change this'
        
        # Staged activation; means that agents first all perform stage 1 before any agent starts stage 2
        # Not yet used but could be very useful when extending the model
        self.schedule = StagedActivation(self, stage_list = ['stage1', 'stage2', 'stage3', 'stage4'])
        
        # Create and store networks
        self.nets = create_networks(['business', 'social'])
        self.business = self.nets[0]
        self.social = self.nets[1]
        
        # Create model variables (-1 for variables that are set later)
        self.phase = phase
        self.steps = 0
        self.interval = -1
        self.draw = -1
        self.violence = -1
        self.trust = -1
        self.usefulness = -1
        self.crimecapital = -1
        self.financialkracht = -1
        self.potential = -1
        self.worth_duration = 0
        
        # Store information dictionaries
        self.business_name_dict = nx.get_node_attributes(self.business,'business_name')
        self.family_name_dict = nx.get_node_attributes(self.social,'family_name')
        self.business_color_dict = nx.get_node_attributes(self.business,'business_color')
        self.family_color_dict = nx.get_node_attributes(self.social,'family_color')
        self.business_edge_colors = nx.get_edge_attributes(self.business,'color')
        self.family_edge_colors = nx.get_edge_attributes(self.social,'color')
        self.business_trust_edges = nx.get_edge_attributes(self.business, 'edge_trust')
        self.business_violence_edges = nx.get_edge_attributes(self.business, 'edge_violence')
        self.business_usefulness_edges = nx.get_edge_attributes(self.business, 'edge_usefulness')
        self.business_crimecapital_edges = nx.get_edge_attributes(self.business, 'edge_crimecapital')
        self.business_financialkracht_edges = nx.get_edge_attributes(self.business, 'edge_financialkracht')
        self.business_edgeIDs = nx.get_edge_attributes(self.business, 'edge_ID')
        self.family_trust_edges = nx.get_edge_attributes(self.social, 'edge_trust')
        self.family_violence_edges = nx.get_edge_attributes(self.social, 'edge_violence')
        self.family_edgeIDs = nx.get_edge_attributes(self.social, 'edge_ID')
        
        # Store a list containing the orphans and give a threshold for their trust
        self.orphans = [key for key, value in self.business_name_dict.items() if 'orphan' in value]
        self.orphan_trust_threshold = 0.75
        
        # Set a separate variable storing the number of the main kingpin node
        self.kingpin_main = [key for key, value in self.business_name_dict.items() if 'kingpin_main' == value][0]

        # Add all nodes to schedule
        for node in self.business:
            a = Agents(node, self)
            self.schedule.add(a)
        
        # Data Collection (probably needs quite some extending for analysis/visualisation)
        self.datacollector = DataCollector(
            model_reporters={"Phases": 'phase',
                            "Names": 'business_name_dict'})
        
    def remove_king(self):
        'Function that removes the current kingpin'
        self.update_dicts()
        for agent in model.schedule.agents:
            if self.business_name_dict[agent.ID] == 'kingpin_main':
                self.business.remove_node(agent.ID)
                self.social.remove_node(agent.ID)
                self.schedule.remove(agent)
                self.update_dicts()
                self.phase = 'removed'
                print('Kingpin has been removed at step: ', self.steps)
                
    def remove_exiled_agents(self):
        'Function that removes agents that have no active ties (edges) to other agents'
        'This function has no use after the addition and implementation of "replace_exiled_agents"'
        'The function is kept intact in case agents are to be removed from the model in a later stage'
        for agent in model.schedule.agents:
            
            # If no edges in business network
            if len([edge for edge in self.business.edges() if agent.ID in edge]) == 0:
                
                # If orphan, also remove from orphan list
                if agent.ID in self.orphans:
                    self.orphans.remove(agent.ID)
                
                # Remove agent completely
                self.business.remove_node(agent.ID)
                self.social.remove_node(agent.ID)
                self.schedule.remove(agent)
        
        self.update_dicts()
                
    def replace_exiled_agents(self):
        'Function that replaces agents that have no active ties (edges) with agents of the same role'
        
        # Place agentIDs in role-specific lists
        stroman_list = [k for k in model.business_name_dict if 'stroman' in model.business_name_dict[k]]
        versneijder_list = [k for k in model.business_name_dict if 'versneijder' in model.business_name_dict[k]]
        beveiliger_list = [k for k in model.business_name_dict if 'beveiliger' in model.business_name_dict[k]]
        plaatserbin_list = [k for k in model.business_name_dict if 'plaatserbin' in model.business_name_dict[k]]
        uithaalmakelaar_list = [k for k in model.business_name_dict if 'uithaalmakelaar' in model.business_name_dict[k]]
        stasher_list = [k for k in model.business_name_dict if 'stasher' in model.business_name_dict[k]]
        poortwachter_list = [k for k in model.business_name_dict if 'poortwachter' in model.business_name_dict[k]]
        leverancier_list = [k for k in model.business_name_dict if 'leverancier' in model.business_name_dict[k]]
        duane_list = [k for k in model.business_name_dict if 'duane' in model.business_name_dict[k]]
        financeer_list = [k for k in model.business_name_dict if 'financeer' in model.business_name_dict[k]]
        transporteur_list = [k for k in model.business_name_dict if 'transporteur' in model.business_name_dict[k]]
        handelaar_list = [k for k in model.business_name_dict if 'handelaar' in model.business_name_dict[k]]
        uithaaler_list = [k for k in model.business_name_dict if 'uithaaler' in model.business_name_dict[k]]
        coordinator_list = [k for k in model.business_name_dict if 'coordinator' in model.business_name_dict[k]]
        chauffeur_list = [k for k in model.business_name_dict if 'chauffeur' in model.business_name_dict[k]]
        exporteur_list = [k for k in model.business_name_dict if 'exporteur' in model.business_name_dict[k]]
        orphan_list = [k for k in model.business_name_dict if 'orphan' in model.business_name_dict[k]]
        kingpin_list = [k for k in model.business_name_dict if 'kingpin' in model.business_name_dict[k] \
                    and model.business_name_dict[k] != 'kingpin_main']
        kingpin_main = [k for k in model.business_name_dict if 'kingpin_main' == model.business_name_dict[k]]
        
        for agent in model.schedule.agents:
            
            # If no edges in business network
            if len([edge for edge in self.business.edges() if agent.ID in edge]) == 0:
                
                add_edge_list(self.business, stroman_list, [agent.ID], 0.15, 'olivedrab', 5) 
                add_edge_list(self.business, versneijder_list, [agent.ID], 0.15, 'lightgreen', 5)  
                add_edge_list(self.business, beveiliger_list, [agent.ID], 0.15, 'limegreen', 5) 
                add_edge_list(self.business, plaatserbin_list, [agent.ID], 0.15, 'lightgreen', 5)  
                add_edge_list(self.business, uithaalmakelaar_list, [agent.ID], 0, 'pink', 80)  
                add_edge_list(self.business, stasher_list, [agent.ID], 0.15, 'white', 5) 
                add_edge_list(self.business, poortwachter_list, [agent.ID], 0.4, 'aqua', 25) 
                add_edge_list(self.business, leverancier_list, [agent.ID], 0.3, 'brown', 50) 
                add_edge_list(self.business, duane_list, [agent.ID], 0.3, 'navy', 45)
                add_edge_list(self.business, financeer_list, [agent.ID], 0.6, 'orangered', 60)
                add_edge_list(self.business, transporteur_list, [agent.ID], 0.2, 'blue', 5) 
                add_edge_list(self.business, handelaar_list, [agent.ID], 0.2, 'crimson', 10)
                add_edge_list(self.business, uithaaler_list, [agent.ID], 0.1, 'lime', 20) 
                add_edge_list(self.business, coordinator_list, [agent.ID], 0.1, 'darkred', 30) 
                add_edge_list(self.business, chauffeur_list, [agent.ID], (1/6), 'green', 50) 
                add_edge_list(self.business, exporteur_list, [agent.ID], 0.25, 'firebrick', 70) 
                add_edge_list(self.business, orphan_list, [agent.ID], (1/3), 'yellow', 80, True) 
                add_edge_list(self.business, kingpin_list, [agent.ID], 0.25, 'orange', 100)
                add_edge_list(self.business, [kingpin_main], [agent.ID], 1, 'red', 100)

        self.update_dicts()
 
    def connect_node(self):
        'Function to find best potential replacement'
        self.update_dicts()
        best_trust = 0
        best_potential = -1
        
        # For each agent
        for agent in model.schedule.agents:
     


    # Uncomment the line below to let orphans only consider 'potential kingpins'
            if 'kingpin' or 'orphan' or 'exporteur' or 'coordinator' or 'handelaar' or 'financeer' or 'leverancier' or 'uithaalmakelaar'in self.business_name_dict[agent.ID]:

            # Check trust of agent among orphans
                 trust_avg = self.check_average_orphan_trust(agent.ID)
            
            # If better than up-to-now best, set as up-to-now best
        if trust_avg > best_trust:
            best_trust = trust_avg
            best_potential = agent
        
        # Set variables to best potential replacement and change the phase
        self.potential = best_potential.ID
        self.link_orphans(best_potential)
        self.update_dicts()
        self.phase = 'chosen'
        print('Potential kingpin has been chosen at step: ', self.steps-1)
    
    def link_orphans(self, agent):
        'Function to link the potential new kingpin to the orphans'
        self.update_dicts()
        
        # Add edges
        add_edge_list(self.business, [agent.ID], self.orphans, 1, 'hotpink', 70)
        
        # Create semi_random trust values
        for o in self.orphans:
            if (agent.ID, o) not in self.business_trust_edges and (o, agent.ID) not in self.business_trust_edges:
                self.business_trust_edges[(o, agent.ID)] = random.uniform(0.35,0.65)
                
        # Set values
        nx.set_edge_attributes(self.business, self.business_trust_edges, 'edge_trust')
        self.update_dicts()
        
    def reduce_orphan_trust(self, agent):
        'Function to reduce the trust that the orphans have in the given agent'
        for o in self.orphans:
            if (agent, o) in self.business_trust_edges:
                new_trust = self.business_trust_edges[(agent, o)] - 0.1
                self.business_trust_edges[(agent, o)] = max(0, new_trust)
            elif (o, agent) in self.business_trust_edges:
                new_trust = self.business_trust_edges[(o, agent)] - 0.1
                self.business_trust_edges[(o, agent)] = max(0, new_trust)
                   
    def pick_kingpin(self):
        'In this function it is decided whether the potential new kingpin is picked or not'
        self.update_dicts()
        trust_avg = self.check_average_orphan_trust(self.potential)
        if trust_avg > self.orphan_trust_threshold:
            self.phase = 'picked'
            self.update_links()
            self.draw = self.steps + 1
            self.worth_duration = 0
            self.orphan_trust_threshold = 0.75
            print('Kingpin has been picked at step: ', self.steps)
        else:
            self.phase = 'removed+'
            self.reduce_orphan_trust(self.potential)
            self.orphan_trust_threshold -= 0.05

            
    def update_links(self):
        'This function makes the potential kingpin that got picked, into the actual kingpin'
        'It sets and resets some model variables, and updates all relevant node/edge information'
        'It also increases the trust that agents have in the kingpin'
        self.update_dicts()

        # Officialise the new kingpin, reset potential, set new node attributes
        self.kingpin_main = self.potential
        self.potential = -1
        self.business_name_dict[self.kingpin_main] = 'kingpin_main'
        self.business_color_dict[self.kingpin_main] = 'red'
        self.family_color_dict[self.kingpin_main] = 'red'
        nx.set_node_attributes(self.business, self.business_name_dict, "business_name")
        nx.set_node_attributes(self.business, self.business_color_dict, "business_color")
        nx.set_node_attributes(self.social, self.family_color_dict, "family_color")
        
        # Set new edges including new color
        add_edge_list(self.business, [self.kingpin_main], self.business.nodes(), 1, 'red', 70)
        add_edge_list(self.social, [self.kingpin_main], self.social.nodes(), 1, 'red', 70)
        
        # Change edge IDs
        for edge in self.business.edges():
            if self.kingpin_main in edge:
                if edge in self.business_edgeIDs:
                    self.business_edgeIDs[edge] = change_ID(self.business_edgeIDs[edge], self.kingpin_main, edge)
        
        # For all agents except kingpin
        for node in self.business.nodes():
            if self.kingpin_main is not node:
                
                # Increase trust in kingpin
                if (self.kingpin_main, node) in self.business_trust_edges:
                    self.business_trust_edges[(self.kingpin_main, node)] = \
                    self.business_trust_edges[(self.kingpin_main, node)] * 1.2
                elif (node, self.kingpin_main) in self.business_trust_edges:
                    self.business_trust_edges[(node, self.kingpin_main)] = \
                    self.business_trust_edges[(node, self.kingpin_main)] * 1.2
                    
                # Or set new trust if non-existant before
                else:
                    self.business_trust_edges[(self.kingpin_main, node)] = random.uniform(0.3, 0.65)
                
                # If not present, create violence edge with kingpin based on average between the two
                if ((self.kingpin_main, node) not in self.business_violence_edges) \
                and ((node, self.kingpin_main) not in self.business_violence_edges):
                    self.business_violence_edges[(self.kingpin_main, node)] = \
                    self.get_new_violence(self.kingpin_main, node)   
        
        # Set new values
        nx.set_edge_attributes(self.business, self.business_trust_edges, 'edge_trust')
        nx.set_edge_attributes(self.business, self.business_violence_edges, 'edge_violence')
        nx.set_edge_attributes(self.business, self.business_edgeIDs, 'edge_ID')
        self.update_dicts()
             
    def get_new_violence(self, kingpin, node):
        'Function that calculates the average violence between two agents'
        'Until now only used to calculate violence values for new edges of the recently picked kingpin'
        for a in self.schedule.agents:
            if a.ID == kingpin:
                kin_viol = a.violence
            elif a.ID == node:
                nod_viol = a.violence
        return (kin_viol + nod_viol) / 2
            
    def check_worthy(self):
        'Function that checks whether the kingpin is still considered worthy by the orphans'
        self.update_dicts()
        trust_avg = self.check_average_orphan_trust(self.kingpin_main)
        if trust_avg < 0.3:
            self.remove_king()
        else: 
            self.worth_duration += 1
        self.update_dicts()

    def check_violence(self):
        'Function to check the average violence of all agents'
        violence = 0
        for agent in self.schedule.agents:
            violence += agent.violence
        violence_average = violence / len(self.schedule.agents)
        self.violence = violence_average
        
    def check_trust(self):
        'Function to check the average trust of all agents'
        trust = 0
        for agent in self.schedule.agents:
            trust += agent.trust
        trust_average = trust / len(self.schedule.agents)
        self.trust = trust_average
        
    def check_usefulness(self):
        'Function to check the average usefulness of all agents'
        usefulness = 0
        for agent in self.schedule.agents:
            usefulness += agent.usefulness
        usefulness_average = usefulness / len(self.schedule.agents)
        self.usefulness = usefulness_average
    
    def check_crimecapital(self):
        'Function to check the average crimecapital of all agents'
        crimecapital = 0
        for agent in self.schedule.agents:
            crimecapital += agent.crimecapital
        crimecapital_average = crimecapital / len(self.schedule.agents)
        self.crimecapital = crimecapital_average
    
    def check_financialkracht(self):
        'Function to check the average financial kracht of all agents'
        financialkracht = 0
        for agent in self.schedule.agents:
            financialkracht += agent.financialkracht
        financialkracht_average = financialkracht / len(self.schedule.agents)
        self.financialkracht = financialkracht_average
        
    def check_average_orphan_trust(self, agent):
        'Function that checks the average trust of the orphans in the given agent'
        trust_level = 0
        for o in self.orphans:
            if (agent, o) in self.business_trust_edges:
                trust_level += self.business_trust_edges[(agent, o)]
            elif (o, agent) in self.business_trust_edges:
                trust_level += self.business_trust_edges[(o, agent)]
        trust_avg = trust_level / len(self.orphans)
        return trust_avg

    def change_edge_trust(self):
        'Function that changes the trust levels of the agents in the business network'
        'In principal, this function is only used when the kingpin just got removed'
        self.update_dicts()
        for edge in self.business.edges(): 
            
            # This string is made so that name checking works one-direction
            name_string = self.family_name_dict[edge[0]] + self.family_name_dict[edge[1]]
        
            # Change edge trust according to the kind of connection (what roles the agents have)
            if 'brother' in self.family_name_dict[edge[0]] and 'brother' in self.family_name_dict[edge[1]]:
                self.business_trust_edges[edge] = min((self.business_trust_edges[edge] * 1.3), 1)               
            elif 'brother' in name_string and 'brother' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'brother' in name_string and 'driver' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'brother' in name_string and 'person' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'cousin' in name_string and 'cousin' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'cousin' in name_string and 'friend' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.7
            elif 'person' in name_string and 'person' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'person' in name_string and 'niece' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'associate' in name_string and 'associate' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'associate' in name_string and 'friend' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'associate' in name_string and 'agent' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'associate' in name_string and 'person' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'nephew' in name_string and 'nephew' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'associate' in name_string and 'nephew' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'buddy' in name_string and 'buddy' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'mate' in name_string and 'buddy' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'mate' in name_string and 'mate' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'colleague' in name_string and 'colleague' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'colleague' in name_string and 'buddy' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'mens' in name_string and 'mens' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'mens' in name_string and 'contact' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'mens' in name_string and 'person' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'niece' in name_string and 'niece' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'niece' in name_string and 'person' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'sister' in name_string and 'sister' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'sister' in name_string and 'statue' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'buurman' in name_string and 'buurman' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'buurman' in name_string and 'statue' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'nephew' in name_string and 'niece' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'nephew' in name_string and 'person' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'friend' in name_string and 'friend' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'friend' in name_string and 'human' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'friend' in name_string and 'associate' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'friend' in name_string and 'driver' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'friend' in name_string and 'person' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'driver' in name_string and 'driver' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'driver' in name_string and 'contact' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'driver' in name_string and 'person' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'person' in name_string and 'person' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'person' in name_string and 'associate' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'person' in name_string and 'human' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'human' in name_string and 'human' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'human' in name_string and 'friend' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'human' in name_string and 'mens' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'human' in name_string and 'agent' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'human' in name_string and 'person' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'agent' in name_string and 'agent' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'statue' in name_string and 'statue' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'agent' in name_string and 'cousin' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            elif 'contact' in name_string and 'contact' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.4
            elif 'contact' in name_string and 'friend' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'contact' in name_string and 'person' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'contact' in name_string and 'agent' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.1
            elif 'contact' in name_string and 'person' in name_string:
                self.business_trust_edges[edge] = self.business_trust_edges[edge] * 1.2
            
           
            
            # Remove if trust among two agents is too low
            if self.business_trust_edges[edge] < 0.5:
                del self.business_trust_edges[edge]
                self.business.remove_edge(edge[0], edge[1])
            
            # Increase if trust among two agents is exceptionally high
            elif self.business_trust_edges[edge] > 0.8:
                self.business_trust_edges[edge] = min((self.business_trust_edges[edge] * 1.005), 1)
                
        # Update phase and attributes
        self.phase = 'removed+'
        nx.set_edge_attributes(self.business, self.business_trust_edges, 'edge_trust')
        self.update_dicts()

    def ran_change_edges(self):
        'Function that randomly changes the trust and violence between agents'
        'Works on both a business and social level'
        self.update_dicts()
        
        business_change_var = 0.01
        social_change_var = 0.005
        
        # Business network
        for edge in self.business.edges():
            
            # Get a different random value for every edge and for trust and violence
            ran_trust = random.choice([-business_change_var, business_change_var])
            ran_violence = random.choice([-business_change_var, business_change_var])
            
            # Remove for low trust, else add the random change but keep between 0 and 1
            if edge in self.business_trust_edges:
                if self.business_trust_edges[edge] < 0.15:
                    del self.business_trust_edges[edge]
                    self.business.remove_edge(edge[0], edge[1])
                else:
                    new_trust = max(min((self.business_trust_edges[edge] + ran_trust), 1), 0)
                    self.business_trust_edges[edge] = new_trust
            
            # All edges should be present in the business trust edge dict, but in case not: 
            else:
                new_trust = random.uniform(0, 1)
                self.business_trust_edges[edge] = new_trust
                
            # Change violence
            if edge in self.business_violence_edges:
                new_violence = max(min((self.business_violence_edges[edge] + ran_violence), 1), 0)
            else:
                new_violence = random.uniform(0, 1) 
            self.business_violence_edges[edge] = new_violence
            
        # Social network
        for edge in self.social.edges():
            ran_trust = random.choice([-social_change_var, social_change_var])
            ran_violence = random.choice([-social_change_var, social_change_var])
            if edge in self.family_trust_edges:
                new_trust = max(min((self.family_trust_edges[edge] + ran_trust), 1), 0)
            else:
                new_trust = random.uniform(0, 1)
            if edge in self.family_violence_edges:
                new_violence = max(min((self.family_violence_edges[edge] + ran_violence), 1), 0)
            else:
                new_violence = random.uniform(0, 1) 
            self.family_trust_edges[edge] = new_trust
            self.family_violence_edges[edge] = new_violence
        
        # Update edges in networks
        nx.set_edge_attributes(self.business, self.business_trust_edges, 'edge_trust')
        nx.set_edge_attributes(self.business, self.business_violence_edges, 'edge_violence')
        nx.set_edge_attributes(self.social, self.family_trust_edges, 'edge_trust')
        nx.set_edge_attributes(self.social, self.family_violence_edges, 'edge_violence')
        self.update_dicts()
    
    def update_dicts(self):
        'Function to update information dictionaries in the model'
        'The function retrieves the info from the networks'
        'The dictionaries can then be used for various applications'
        self.business_name_dict = nx.get_node_attributes(self.business,'business_name')
        self.family_name_dict = nx.get_node_attributes(self.social,'family_name')
        self.business_color_dict = nx.get_node_attributes(self.business,'business_color')
        self.family_color_dict = nx.get_node_attributes(self.social,'family_color')
        self.business_edge_colors = nx.get_edge_attributes(self.business,'color')
        self.family_edge_colors = nx.get_edge_attributes(self.social,'color')
        self.business_trust_edges = nx.get_edge_attributes(self.business, 'edge_trust')
        self.business_violence_edges = nx.get_edge_attributes(self.business, 'edge_violence')
        self.business_usefulness_edges = nx.get_edge_attributes(self.business, 'edge_usefulness')
        self.business_crimecapital_edges = nx.get_edge_attributes(self.business, 'edge_crimecapital')
        self.business_financialkracht_edges = nx.get_edge_attributes(self.business, 'edge_financialkracht')
        self.business_edgeIDs = nx.get_edge_attributes(self.business, 'edge_ID')
        self.family_trust_edges = nx.get_edge_attributes(self.social, 'edge_trust')
        self.family_violence_edges = nx.get_edge_attributes(self.social, 'edge_violence')
        self.family_edgeIDs = nx.get_edge_attributes(self.social, 'edge_ID')

    def draw_networks(self):
        'Function to draw the networks involved'
        self.update_dicts() 

        # Business network
        nx.draw(self.business, with_labels=True, edge_color=self.business_edge_colors.values(), \
                node_color=self.business_color_dict.values())
        plt.show()
        
        # Social network
        nx.draw(self.social, with_labels=True, edge_color=self.family_edge_colors.values(), \
                node_color=self.family_color_dict.values())
        plt.show()
        
        
    def step(self):
        'This function is the "engine" of the model'
        'After the model is created, one can call this step function to let the model run'
        'Some of the functionalities of the model will be performed every step'
        'For other functions it depends on the phase whether it will be performed'
        
        # Collect data at start of each step
        self.datacollector.collect(self)
        
        # Remove agents that have no edges with other agents anymore
        self.replace_exiled_agents()
        
        # Stop execution if no more agents present (after recent changes, this should not be necessary anymore)
        if (len(self.schedule.agents)) == 0 or (len(self.orphans) == 0):
            sys.exit('No more agents in the model')
    
        # Randomly change trust and violence edges at each step, and update averages
        self.ran_change_edges()
        self.check_violence()
        self.check_trust()
        self.check_usefulness()
        self.check_crimecapital()
        self.check_financialkracht()
        
        # Set interval variable
        self.interval = random.randrange(self.steps, self.steps + 5)
        
        # Remove king if at start
        if self.phase == 'start':
            self.remove_king()
            
        # If just removed, update ties accordingly and draw the network
        elif self.phase == 'removed':
            self.change_edge_trust()
            self.draw_networks()
        
        # If removed, choose best potential kingpin (self.interval assures that some arbitrary time passes)
        elif (self.phase == 'removed+') and (self.steps == self.interval):
            self.connect_node()
            
        # If chosen and some more arbitrary time has passed, decide whether or not to pick the kingpin
        elif (self.phase == 'chosen') and (self.steps == self.interval):
            self.pick_kingpin()
            
        # If kingpin is picked, decide whether the kingpin is still worthy (remove if not)
        elif (self.phase == 'picked'):
            
            # Draw network if just picked
            if (self.steps == self.draw):
                self.draw_networks()
                
            self.check_worthy()
#             if self.worth_duration > 29:
#                 print('we are here')
#                 sys.exit('New kingpin has been deemed worthy for 30 days')

        # Keep track of the steps
        self.steps += 1

# %%
'This is were the model is actually created'
simulate = (
    # First, we initialise the model:
model = ReplacementModel(nodes, edges, params)

# Then, we can make it run for a set amount of steps:
# for i in range(1000):
    if model.worth_duration < 300:
        model.step()
#     else:
#         print('New kingpin has been deemed worthy for 300 days')
#         break
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-118c280ec64c> in <module>
#       2
#       3 # First, we initialise the model:
# ----> 4 model = ReplacementModel()
#       5
#       6 # Then, we can make it run for a set amount of steps:
#
# <ipython-input-15-197f8c06d4c6> in __init__(self, phase)
#      13
#      14         # Create and store networks
# ---> 15         self.nets = create_networks(['business', 'social'])
#      16         self.business = self.nets[0]
#      17         self.social = self.nets[1]
#
# <ipython-input-13-d9a1cfcf328c> in create_networks(networks, N)
#      59
#      60     # Make dictionaries for attributes
# ---> 61     business_color_dict = make_dict(business_role_list, 'color')
#      62     family_color_dict = make_dict(family_role_list, 'color')
# ...

# %%
gini = model.datacollector.get_model_vars_dataframe()

# %%
gini[0:60]

# %%
model.business_name_dict

# %%
broker = [k for k in model.business_name_dict if 'broker' in model.business_name_dict[k]]

# %%
broker = [k for k in model.business_name_dict if 'kingpin' in model.business_name_dict[k] and model.business_name_dict[k] != 'kingpin_main']

# %%
broker
